# %%
import pandas as pd
import os

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# --- 1. CAMINHOS ---

# Caminho de LEITURA (o arquivo que você quer renomear)
path_leitura_ofertas= '../../../planilhas/limpo/modulo_2/inscritos_coluna_filtro_renda_regiao/ajustado_fies_pfies_inscritos.csv'

# Caminho de SAÍDA (onde salvar o arquivo com nomes novos)
path_salvar_ofertas = '../../../planilhas/limpo/modulo_3/limpar_e_padronizar_colunas/inscritos_limpo.csv'


mapa_nomes_curto = {
    # Chaves de processo
    'ano_processo_seletivo_inscricao': 'ano',
    'semestre_processo_seletivo_inscricao': 'semestre',
    'codigo_grupo_preferencia_inscricao': 'codigo_grupo_preferencia',
    'classificacao_inscricao': 'classificacao',
    'opcoes_cursos_inscricao_inscricao': 'opcao_curso',
    
    # Dados do Estudante
    'id_estudante_inscricao': 'id_estudante',
    'sexo_inscricao': 'sexo',
    'data_nascimento_inscricao': 'data_nascimento',
    'uf_residencia_inscricao': 'uf_residencia',
    'municipio_residencia_inscricao': 'municipio_residencia',
    'etnia_cor_inscricao': 'etnia_cor',
    'pessoa_com_deficiencia_inscricao': 'pessoa_com_deficiencia',
    
    # Escolaridade
    'concluiu_ensino_medio_escola_publica_inscricao': 'ensino_medio_escola_publica',
    'ano_conclusao_ensino_medio_inscricao': 'ano_conclusao_em',
    'concluiu_curso_superior_inscricao': 'concluiu_curso_superior',
    'professor_rede_publica_ensino_inscricao': 'professor_rede_publica',
    
    # Renda e Grupo Familiar
    'numero_membros_grupo_familiar_inscricao': 'membros_grupo_familiar',
    'renda_familiar_mensal_bruta_inscricao': 'renda_familiar_bruta',
    'renda_mensal_bruta_per_capita_inscricao': 'renda_per_capita',
    
    # Detalhes da Vaga (Grupo de Preferência)
    'regiao_grupo_preferencia_inscricao': 'regiao_gp',
    'uf_grupo_preferencia_inscricao': 'uf_gp',
    'codigo_microrregiao_inscricao': 'codigo_microrregiao_gp',
    'microrregiao_inscricao': 'microrregiao_gp',
    'codigo_mesorregiao_inscricao': 'codigo_mesorregiao_gp',
    'mesorregiao_inscricao': 'mesorregiao_gp',
    'conceito_curso_gp_inscricao': 'conceito_curso_gp',
    'nota_corte_grupo_preferencia_inscricao': 'nota_corte_gp',
    
    # Detalhes da IES
    'nome_mantenedora_inscricao': 'nome_mantenedora',
    'natureza_juridica_mantenedora_inscricao': 'natureza_juridica_mantenedora',
    'cnpj_mantenedora_inscricao': 'cnpj_mantenedora',
    'codigo_e_mec_mantenedora_inscricao': 'codigo_mec_mantenedora',
    'nome_ies_inscricao': 'nome_ies',
    'codigo_e_mec_ies_inscricao': 'codigo_mec_ies',
    'organizacao_academica_ies_inscricao': 'organizacao_academica_ies',
    'municipio_ies_inscricao': 'municipio_ies',
    'uf_ies_inscricao': 'uf_ies',
    
    # Detalhes do Local de Oferta
    'nome_local_oferta_inscricao': 'nome_local_oferta',
    'codigo_local_oferta_inscricao': 'codigo_local_oferta',
    'municipio_local_oferta_inscricao': 'municipio_local_oferta',
    'uf_local_oferta_inscricao': 'uf_local_oferta',
    
    # Detalhes do Curso
    'codigo_curso_inscricao': 'codigo_curso',
    'nome_curso_inscricao': 'nome_curso',
    'turno_inscricao': 'turno',
    'grau_inscricao': 'grau',
    'conceito_curso_inscricao': 'conceito_curso',
    'area_conhecimento_inscricao': 'area_conhecimento',
    'subarea_conhecimento_inscricao': 'subarea_conhecimento',

    # Notas ENEM
    'media_nota_enem_inscricao': 'media_enem',
    'ano_enem_inscricao': 'ano_enem',
    'nota_redacao_inscricao': 'nota_redacao',
    'nota_matematica_inscricao': 'nota_matematica',
    'nota_linguagens_inscricao': 'nota_linguagens',
    'nota_ciencias_natureza_inscricao': 'nota_ciencias_natureza',
    'nota_ciencias_humanas_inscricao': 'nota_ciencias_humanas',
    
    # Financiamento
    'beneficiado_creduc_ou_fies_inscricao': 'beneficiado_creduc_fies',
    'situacao_inscricao_fies_inscricao': 'situacao_fies',
    'percentual_financiamento_inscricao': 'percentual_financiamento',
    'semestre_financiamento_inscricao': 'semestre_financiamento',
    'qtde_semestre_financiado_inscricao': 'qtde_semestre_financiado',
    
    # Colunas CINE
    'NO_CURSO': 'nome_curso_cine',
    'CO_CURSO': 'codigo_curso_cine',
    'CO_CINE_AREA_GERAL': 'codigo_cine_area_geral',
    'NO_CINE_AREA_GERAL': 'nome_cine_area_geral',

}

# --- 3. PROCESSAMENTO ---
print(f"Lendo arquivo de ofertas: {path_leitura_ofertas}")



df_ofertas = pd.read_csv(path_leitura_ofertas, low_memory=False) # Adicionado low_memory=False

#df_ofertas= df_ofertas.drop(columns=['limite_temp']).copy()

print("Renomeando colunas...")
df_ofertas_renomeado = df_ofertas.rename(columns=mapa_nomes_curto)

# Cria o diretório se ele não existir
os.makedirs(os.path.dirname(path_salvar_ofertas), exist_ok=True)

print(f"Salvando arquivo renomeado em: {path_salvar_ofertas}")
df_ofertas_renomeado.to_csv(path_salvar_ofertas, index=False)

print("\n--- Processo Concluído (Ofertas) ---")

print("\nNovos nomes de colunas:")
print(df_ofertas_renomeado.columns.to_list())


pd.set_option('display.max_rows', None) # Para mostrar todos os nomes
pd.set_option('display.max_columns', None)

display(df_ofertas_renomeado.head())#type: ignore
# Out:
# Lendo arquivo de ofertas: ../../../planilhas/limpo/modulo_2/inscritos_coluna_filtro_renda_regiao/ajustado_fies_pfies_inscritos.csv
# Renomeando colunas...
# Salvando arquivo renomeado em: ../../../planilhas/limpo/modulo_3/limpar_e_padronizar_colunas/inscritos_limpo.csv
#
# --- Processo Concluído (Ofertas) ---
#
# Novos nomes de colunas:
# ['ano', 'semestre', 'codigo_grupo_preferencia', 'classificacao', 'id_estudante', 'sexo', 'data_nascimento', 'uf_residencia', 'municipio_residencia', 'etnia_cor', 'pessoa_com_deficiencia', 'ensino_medio_escola_publica', 'ano_conclusao_em', 'concluiu_curso_superior', 'beneficiado_creduc_fies', 'professor_rede_publica', 'membros_grupo_familiar', 'renda_familiar_bruta', 'renda_per_capita', 'regiao_gp', 'uf_gp', 'codigo_microrregiao_gp', 'microrregiao_gp', 'codigo_mesorregiao_gp', 'mesorregiao_gp', 'conceito_curso_gp', 'area_conhecimento', 'subarea_conhecimento', 'nota_corte_gp', 'opcao_curso', 'nome_mantenedora', 'natureza_juridica_mantenedora', 'cnpj_mantenedora', 'codigo_mec_mantenedora', 'nome_ies', 'codigo_mec_ies', 'organizacao_academica_ies', 'municipio_ies', 'uf_ies', 'nome_local_oferta', 'codigo_local_oferta', 'municipio_local_oferta', 'uf_local_oferta', 'codigo_curso', 'nome_curso', 'turno', 'grau', 'conceito_curso', 'media_enem', 'ano_enem', 'nota_redacao', 'nota_matematica', 'nota_linguagens', 'nota_ciencias_natureza', 'nota_ciencias_humanas', 'situacao_fies', 'percentual_financiamento', 'semestre_financiamento', 'qtde_semestre_financiado', 'nome_curso_cine', 'codigo_curso_cine', 'codigo_cine_area_geral', 'nome_cine_area_geral', 'regiao_residencia', 'modalidade_fies']
#     ano  semestre  codigo_grupo_preferencia  classificacao  id_estudante sexo  \
# 0  2019         1                     46540              1      97492018    F
# 1  2019         1                     46540              1      97492018    F
# 2  2019         1                     46540              1      97492018    F
# 3  2019         1                     46540              2      12625187    F
# 4  2019         1                     46540              2      12625187    F
#
#   data_nascimento uf_residencia municipio_residencia etnia_cor  \
# 0      23/09/1997            SC  SÃO MIGUEL DO OESTE    BRANCA
# 1      23/09/1997            SC  SÃO MIGUEL DO OESTE    BRANCA
# 2      23/09/1997            SC  SÃO MIGUEL DO OESTE    BRANCA
# 3      13/01/1990            PR             CURITIBA    BRANCA
# 4      13/01/1990            PR             CURITIBA    BRANCA
#
#   pessoa_com_deficiencia ensino_medio_escola_publica  ano_conclusao_em  \
# 0                    NÃO                         NÃO              2014
# 1                    NÃO                         NÃO              2014
# 2                    NÃO                         NÃO              2014
# 3                    NÃO                         NÃO              2008
# 4                    NÃO                         NÃO              2008
#
#   concluiu_curso_superior beneficiado_creduc_fies professor_rede_publica  \
# 0                     NÃO                     Não                    NÃO
# 1                     NÃO                     Não                    NÃO
# 2                     NÃO                     Não                    NÃO
# 3                     NÃO                     Não                    NÃO
# 4                     NÃO                     Não                    NÃO
#
#    membros_grupo_familiar  renda_familiar_bruta  renda_per_capita regiao_gp  \
# 0                       2                6495.0            2165.0       SUL
# 1                       2                6495.0            2165.0       SUL
# 2                       2                6495.0            2165.0       SUL
# 3                       2                8901.0            2967.0       SUL
# 4                       2                8901.0            2967.0       SUL
#
#     uf_gp  codigo_microrregiao_gp microrregiao_gp  codigo_mesorregiao_gp  \
# 0  PARANÁ                   41037        CURITIBA                   4110
# 1  PARANÁ                   41037        CURITIBA                   4110
# 2  PARANÁ                   41037        CURITIBA                   4110
# 3  PARANÁ                   41037        CURITIBA                   4110
# 4  PARANÁ                   41037        CURITIBA                   4110
#
#               mesorregiao_gp conceito_curso_gp        area_conhecimento  \
# 0  METROPOLITANA DE CURITIBA                 4  CURSOS NAO PRIORITARIOS
# 1  METROPOLITANA DE CURITIBA                 4  CURSOS NAO PRIORITARIOS
# 2  METROPOLITANA DE CURITIBA                 4  CURSOS NAO PRIORITARIOS
# 3  METROPOLITANA DE CURITIBA                 4  CURSOS NAO PRIORITARIOS
# 4  METROPOLITANA DE CURITIBA                 4  CURSOS NAO PRIORITARIOS
#
#                                 subarea_conhecimento  nota_corte_gp  \
# 0  CIÊNCIAS BIOLÓGICAS (BEL), BIOMEDICINA, BIOTEC...          635.7
# 1  CIÊNCIAS BIOLÓGICAS (BEL), BIOMEDICINA, BIOTEC...          635.7
# 2  CIÊNCIAS BIOLÓGICAS (BEL), BIOMEDICINA, BIOTEC...          635.7
# 3  CIÊNCIAS BIOLÓGICAS (BEL), BIOMEDICINA, BIOTEC...          635.7
# 4  CIÊNCIAS BIOLÓGICAS (BEL), BIOMEDICINA, BIOTEC...          635.7
#
#    opcao_curso                                   nome_mantenedora  \
# 0            2             ASSOCIACAO PARANAENSE DE CULTURA - APC
# 1            3        COMPLEXO DE ENSINO SUPERIOR DO BRASIL LTDA.
# 2            1  ASSOCIACAO HOSPITALAR DE PROT INFANCIA DR RAUL...
# 3            2             ASSOCIACAO PARANAENSE DE CULTURA - APC
# 4            1  ASSOCIACAO HOSPITALAR DE PROT INFANCIA DR RAUL...
#
#                        natureza_juridica_mantenedora  cnpj_mantenedora  \
# 0  PESSOA JURÍDICA DE DIREITO PRIVADO - SEM FINS ...      7.670000e+13
# 1                        PRIVADA COM FINS LUCRATIVOS      2.740000e+12
# 2                        PRIVADA SEM FINS LUCRATIVOS      7.660000e+13
# 3  PESSOA JURÍDICA DE DIREITO PRIVADO - SEM FINS ...      7.670000e+13
# 4                        PRIVADA SEM FINS LUCRATIVOS      7.660000e+13
#
#    codigo_mec_mantenedora                                    nome_ies  \
# 0                      10  PONTIFÍCIA UNIVERSIDADE CATÓLICA DO PARANÁ
# 1                     963     CENTRO UNIVERSITÁRIO AUTÔNOMO DO BRASIL
# 2                    1812                 FACULDADES PEQUENO PRÍNCIPE
# 3                      10  PONTIFÍCIA UNIVERSIDADE CATÓLICA DO PARANÁ
# 4                    1812                 FACULDADES PEQUENO PRÍNCIPE
#
#    codigo_mec_ies organizacao_academica_ies municipio_ies uf_ies  \
# 0              10              UNIVERSIDADE      CURITIBA     PR
# 1            3602      CENTRO UNIVERSITÁRIO      CURITIBA     PR
# 2            2787                FACULDADE       CURITIBA     PR
# 3              10              UNIVERSIDADE      CURITIBA     PR
# 4            2787                FACULDADE       CURITIBA     PR
#
#          nome_local_oferta  codigo_local_oferta municipio_local_oferta  \
# 0  PUCPR - CAMPUS CURITIBA               657676               CURITIBA
# 1             UNIDADE SEDE               659556               CURITIBA
# 2    CAMPUS AVENIDA IGUAÇU              1095611               CURITIBA
# 3  PUCPR - CAMPUS CURITIBA               657676               CURITIBA
# 4    CAMPUS AVENIDA IGUAÇU              1095611               CURITIBA
#
#   uf_local_oferta  codigo_curso           nome_curso       turno       grau  \
# 0              PR           861  CIÊNCIAS BIOLÓGICAS    MATUTINO  SEMESTRAL
# 1              PR         94925          BIOMEDICINA    MATUTINO  SEMESTRAL
# 2              PR         91175          BIOMEDICINA  VESPERTINO  SEMESTRAL
# 3              PR           861  CIÊNCIAS BIOLÓGICAS    MATUTINO  SEMESTRAL
# 4              PR         91175          BIOMEDICINA  VESPERTINO  SEMESTRAL
#
#   conceito_curso  media_enem ano_enem  nota_redacao  nota_matematica  \
# 0              4      714.42   2018.0         920.0            738.0
# 1              4      714.42   2018.0         920.0            738.0
# 2              4      714.42   2018.0         920.0            738.0
# 3              4      707.26   2018.0         920.0            725.3
# 4              4      707.26   2018.0         920.0            725.3
#
#    nota_linguagens  nota_ciencias_natureza  nota_ciencias_humanas  \
# 0            620.1                   621.8                  672.2
# 1            620.1                   621.8                  672.2
# 2            620.1                   621.8                  672.2
# 3            589.9                   609.8                  691.3
# 4            589.9                   609.8                  691.3
#
#     situacao_fies  percentual_financiamento semestre_financiamento  \
# 0  NÃO CONTRATADO                       NaN
# 1  NÃO CONTRATADO                       NaN
# 2  NÃO CONTRATADO                       NaN
# 3  NÃO CONTRATADO                       NaN
# 4  NÃO CONTRATADO                       NaN
#
#    qtde_semestre_financiado      nome_curso_cine  codigo_curso_cine  \
# 0                       NaN  Ciências Biológicas              861.0
# 1                       NaN          Biomedicina            94925.0
# 2                       NaN          Biomedicina            91175.0
# 3                       NaN  Ciências Biológicas              861.0
# 4                       NaN          Biomedicina            91175.0
#
#    codigo_cine_area_geral                         nome_cine_area_geral  \
# 0                     5.0  Ciências naturais, matemática e estatística
# 1                     9.0                            Saúde e bem-estar
# 2                     9.0                            Saúde e bem-estar
# 3                     5.0  Ciências naturais, matemática e estatística
# 4                     9.0                            Saúde e bem-estar
#
#   regiao_residencia modalidade_fies
# 0               Sul    Modalidade I
# 1               Sul    Modalidade I
# 2               Sul    Modalidade I
# 3               Sul    Modalidade I
# 4               Sul    Modalidade I

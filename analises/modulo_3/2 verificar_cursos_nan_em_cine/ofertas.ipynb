# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# --- 1. CAMINHO E LEITURA ---
path_inscritos_limpo = '../../../planilhas/limpo/modulo_3/limpar_e_padronizar_colunas/ofertas_limpo.csv' 

print(f"Lendo dataset: {path_inscritos_limpo}")
try:
    df = pd.read_csv(path_inscritos_limpo, low_memory=False)
    print(f"DataFrame carregado. Shape: {df.shape}\n")
except FileNotFoundError:
    print(f"!!! ERRO: Arquivo não encontrado em: {path_inscritos_limpo}")
    raise SystemExit("Arquivo de entrada não encontrado.")

# --- 2. DEFINIÇÃO DAS COLUNAS CHAVE ---
# Usar os nomes padronizados e curtos
COL_NOME_CURSO_INSCRITO = 'nome_curso'       # Nome do curso que o aluno se inscreveu (o que queremos ver)
COL_NOME_CURSO_CINE = 'nome_cine_area_geral'      # Nome do curso CINE (filtro)
COL_CODIGO_CINE = 'codigo_curso_cine'        # Código CINE (filtro)

# Garantir que as colunas existem
for col in [COL_NOME_CURSO_INSCRITO, COL_NOME_CURSO_CINE, COL_CODIGO_CINE]:
    if col not in df.columns:
        print(f"!!! ERRO: Coluna essencial '{col}' não encontrada no DataFrame.")
        print(f"Colunas disponíveis: {df.columns.to_list()}")
        raise SystemExit("Colunas CINE ausentes após renomeação.")


# --- PEDIDO 1: Quais nomes de curso têm CÓDIGO CINE (codigo_curso_cine) == NaN ---
print("\n=======================================================")
print("  PEDIDO 1: LISTA DE NOMES DE CURSO COM CÓDIGO CINE AUSENTE")
print("=======================================================")

# Filtro 1: Código CINE está faltando (NaN)
filtro_cod_cine_nan = df[COL_CODIGO_CINE].isna()

# Pega os nomes dos cursos originais e remove duplicatas para listar os títulos
cursos_sem_cod_cine = df[filtro_cod_cine_nan][COL_NOME_CURSO_INSCRITO].dropna().unique()

print(f"Total de registros com {COL_CODIGO_CINE} NaN: {filtro_cod_cine_nan.sum()}")
print(f"Total de Nomes de Curso ÚNICOS sem {COL_CODIGO_CINE}: {len(cursos_sem_cod_cine)}\n")
print(">>> LISTA DE NOMES DE CURSO (ORIGINAIS) <<<")
for nome in cursos_sem_cod_cine:
    print(f"- {nome}")
print("\n" + "=" * 50)


# --- PEDIDO 2: CÓDIGO CINE (NaN) E NOME CURSO CINE (NaN) ---
print("\n=================================================================================")
print("  PEDIDO 2: REGISTROS ONDE CÓDIGO CINE E NOME CURSO CINE ESTÃO AUSENTES (Totalmente Desconhecidos)")
print("=================================================================================")

# Filtro 2: Código CINE está faltando E o Nome do Curso CINE está faltando
filtro_duplo_cine_nan = ((df[COL_CODIGO_CINE].isna()) & (df[COL_NOME_CURSO_CINE].isna()))

# Contagem e amostra para visualização
total_duplo_cine_nan = filtro_duplo_cine_nan.sum()
amostra_duplo_cine_nan = df[filtro_duplo_cine_nan]

print(f"Total de registros com {COL_CODIGO_CINE} E {COL_NOME_CURSO_CINE} NaN: {total_duplo_cine_nan}")

if total_duplo_cine_nan > 0:
    print("\nAmostra (head) dos registros. Nome do Curso Original (nome_curso) com Classificação CINE Ausente:")
    
    # Exibir a coluna NOME_CURSO_INSCRITO (o título original) e as colunas CINE (para provar que são NaN)
    display(amostra_duplo_cine_nan['nome_curso'])# type: ignore
else:
    print("\nNenhum registro encontrado onde AMBAS as informações CINE estão NaN simultaneamente.")
    
print("=" * 50)
# Out:
# Lendo dataset: ../../../planilhas/limpo/modulo_3/limpar_e_padronizar_colunas/ofertas_limpo.csv
# DataFrame carregado. Shape: (143622, 70)
#
#
# =======================================================
#   PEDIDO 1: LISTA DE NOMES DE CURSO COM CÓDIGO CINE AUSENTE
# =======================================================
# Total de registros com codigo_curso_cine NaN: 6119
# Total de Nomes de Curso ÚNICOS sem codigo_curso_cine: 216
#
# >>> LISTA DE NOMES DE CURSO (ORIGINAIS) <<<
# - PROCESSOS GERENCIAIS
# - RELAÇÕES PÚBLICAS
# - ANÁLISE E DESENVOLVIMENTO DE SISTEMAS
# - SEGURANÇA PÚBLICA
# - ARQUITETURA E URBANISMO
# - ADMINISTRAÇÃO
# - CONSTRUÇÃO DE EDIFÍCIOS
# - MARKETING
# - FORMAÇÃO PEDAGÓGICA PARA PORTADORES DE ENSINO SUPERIOR
# - ENGENHARIA AMBIENTAL E SANITÁRIA
# - GESTÃO DA QUALIDADE
# - ENGENHARIA DE PETRÓLEO
# - SERVIÇO SOCIAL
# - GESTÃO HOSPITALAR
# - ENGENHARIA DE PRODUÇÃO
# - GESTÃO DE RECURSOS HUMANOS
# - SERVIÇOS PENAIS
# - BIOMEDICINA
# - MÚSICA
# - ENGENHARIA DE COMPUTAÇÃO
# - COMUNICAÇÃO SOCIAL
# - GESTÃO DE COOPERATIVAS
# - PEDAGOGIA
# - MEDICINA VETERINÁRIA
# - ENGENHARIA MECÂNICA
# - NEGÓCIOS IMOBILIÁRIOS
# - JOGOS DIGITAIS
# - AGRONEGÓCIO
# - QUÍMICA
# - NUTRIÇÃO
# - CIÊNCIAS DA ACUPUNTURA
# - SISTEMAS DE INFORMAÇÃO
# - LOGÍSTICA
# - COMUNICAÇÃO INSTITUCIONAL
# - LETRAS PORTUGUÊS E INGLÊS
# - TURISMO
# - GESTÃO PÚBLICA
# - LETRAS - PORTUGUÊS
# - GEOGRAFIA
# - SISTEMAS ELÉTRICOS
# - EDUCAÇÃO FÍSICA
# - ENGENHARIA QUÍMICA
# - SEGURANÇA NO TRABALHO
# - ENGENHARIA ELÉTRICA
# - MODA
# - RELAÇÕES INTERNACIONAIS
# - GESTÃO COMERCIAL
# - SEGURANÇA DA INFORMAÇÃO
# - ESTÉTICA E COSMÉTICA
# - PRODUÇÃO CULTURAL
# - JORNALISMO
# - REDES DE COMPUTADORES
# - FARMÁCIA
# - GASTRONOMIA
# - CIÊNCIAS BIOLÓGICAS
# - ENGENHARIA CIVIL
# - ENGENHARIA DE CONTROLE E AUTOMAÇÃO
# - SECRETARIADO
# - MANUTENÇÃO INDUSTRIAL
# - TEOLOGIA
# - CIÊNCIAS CONTÁBEIS
# - FISIOTERAPIA
# - DESIGN DE MODA
# - LETRAS - FRANCÊS
# - HOTELARIA
# - ARTES CÊNICAS
# - RADIOLOGIA
# - ENFERMAGEM
# - DESIGN DE INTERIORES
# - ENGENHARIA DE ENERGIA
# - HISTÓRIA
# - MATEMÁTICA
# - GESTÃO FINANCEIRA
# - COMUNICAÇÃO SOCIAL - PUBLICIDADE E PROPAGANDA
# - LETRAS - PORTUGUÊS E INGLÊS
# - CIÊNCIAS DA COMPUTAÇÃO
# - PETRÓLEO E GÁS
# - BIG DATA E INTELIGÊNCIA ANALÍTICA
# - SISTEMAS PARA INTERNET
# - GESTÃO DE SERVIÇOS JURÍDICOS E NOTARIAIS
# - FÍSICA
# - CIÊNCIA DA COMPUTAÇÃO
# - LETRAS
# - PSICOLOGIA
# - ENERGIAS RENOVÁVEIS
# - GESTÃO DE SEGURANÇA PRIVADA
# - GESTÃO AMBIENTAL
# - MUSEOLOGIA
# - CIÊNCIA POLÍTICA
# - FOTOGRAFIA
# - GESTÃO DA PRODUÇÃO INDUSTRIAL
# - ENGENHARIA BIOMÉDICA
# - DESIGN GRÁFICO
# - LETRAS - PORTUGUÊS E ESPANHOL
# - LETRAS - LÍNGUA PORTUGUESA
# - GESTÃO DA TECNOLOGIA DA INFORMAÇÃO
# - ENGENHARIA DE ALIMENTOS
# - PUBLICIDADE E PROPAGANDA
# - BANCO DE DADOS
# - SUCROALCOOLEIRA
# - ELETRÔNICA INDUSTRIAL
# - BIBLIOTECONOMIA
# - FILOSOFIA
# - PSICOPEDAGOGIA
# - PRODUÇÃO SUCROALCOOLEIRA
# - ENGENHARIA DA COMPUTAÇÃO
# - ENGENHARIA MECATRÔNICA
# - LETRAS - ESPANHOL
# - PILOTAGEM PROFISSIONAL DE AERONAVES
# - FONOAUDIOLOGIA
# - CIÊNCIAS ECONÔMICAS
# - VITICULTURA E ENOLOGIA
# - TRANSPORTE TERRESTRE
# - MARKETING DIGITAL
# - ENGENHARIA
# - GESTÃO DO AGRONEGÓCIO
# - CIÊNCIAS SOCIAIS
# - SISTEMAS DE TELECOMUNICAÇÕES
# - GESTÃO PORTUÁRIA
# - COMUNICAÇÃO SOCIAL - RADIO E TELEVISÃO
# - LETRAS - INGLÊS
# - DIREITO
# - ENGENHARIA AMBIENTAL
# - ESTÉTICA E COSMETOLOGIA
# - EVENTOS
# - DESIGN DE PRODUTO
# - DANÇA
# - CIÊNCIA ECONÔMICA
# - PRODUÇÃO DE GRÃOS
# - AGRONOMIA
# - BIOLOGIA
# - ENGENHARIA AGRONÔMICA
# - ENGENHARIA DE ENERGIAS
# - GESTÃO DE RECURSOS HÍDRICOS
# - DEFESA CIBERNÉTICA
# - CONSTRUÇÃO NAVAL
# - MEDIAÇÃO
# - COMÉRCIO EXTERIOR
# - GESTÃO DE RESÍDUOS SÓLIDOS
# - GEOPROCESSAMENTO
# - TERAPIA OCUPACIONAL
# - GESTÃO DE NEGÓCIOS E INOVAÇÃO
# - GESTÃO DE TURISMO
# - PROCESSOS ESCOLARES
# - INTERDISCIPLINAR EM CIÊNCIA E TECNOLOGIA
# - ACUPUNTURA
# - COMUNICAÇÃO SOCIAL - JORNALISMO
# - PRODUÇÃO MULTIMÍDIA
# - COMUNICAÇÃO SOCIAL - RADIALISMO (RÁDIO E TV)
# - DESIGN
# - ENGENHARIA DE SISTEMAS
# - GESTÃO DESPORTIVA E DE LAZER
# - SISTEMA DE INFORMAÇÃO
# - LETRAS - LIBRAS
# - CONTROLE DE OBRAS
# - TECNOLOGIA E DESIGN DE NEGÓCIOS
# - GESTÃO DE SERVIÇOS JURÍDICOS, NOTARIAIS E DE REGISTRO
# - ENGENHARIA DE BIOPROCESSOS E BIOTECNOLOGIA
# - DESENVOLVIMENTO PARA WEB
# - CIÊNCIA DA INFORMAÇÃO
# - ENGENHARIA AGRÍCOLA
# - ELETROTÉCNICA INDUSTRIAL
# - PRODUÇÃO GRÁFICA DIGITAL
# - GESTÃO DE EMPREENDIMENTOS ESPORTIVOS
# - VISAGISMO E TERAPIAS CAPILARES
# - ARTES VISUAIS
# - NORMAL  SUPERIOR
# - GESTÃO DE NEGÓCIOS NO VAREJO
# - CINEMA E AUDIOVISUAL
# - EDUCAÇÃO ARTÍSTICA
# - RÁDIO, TV E INTERNET
# - COMUNICAÇÃO EM CRIAÇÃO E DESENVOLVIMENTO DE WEB SITES E DESIGN
# - COMUNICAÇÃO EMPRESARIAL
# - SEGURANÇA NO TRÂNSITO
# - SECRETARIADO EXECUTIVO
# - PRODUÇÃO PUBLICITÁRIA
# - TURISMO RECEPTIVO
# - COMUNICAÇÃO SOCIAL - CINEMA E AUDIOVISUAL
# - ENGENHARIA DE TELECOMUNICAÇÕES
# - ESTÉTICA
# - COMUNICAÇÃO SOCIAL - RELAÇÕES PÚBLICAS
# - FORMAÇÃO DE DOCENTES PARA A EDUCAÇÃO BÁSICA
# - ENGENHARIA ELETRÔNICA
# - GESTÃO MERCADOLÓGICA
# - COMUNICAÇÃO SOCIAL COM HABILITAÇÃO EM PUBLICIDADE E PROPAGANDA
# - MULTIMÍDIA
# - SERVIÇOS JUDICIAIS
# - ODONTOLOGIA
# - GESTÃO DE TURISMO RECEPTIVO
# - AGROINDUSTRIA
# - LETRAS - LINGUAGEM AUDIOVISUAL
# - PRODUÇÃO AUDIOVISUAL
# - COMUNICAÇÃO PARA WEB
# - ESTILISMO
# - FORMAÇÃO PEDAGÓGICA DE DOCENTES PARA A EDUCAÇÃO BÁSICA E PROFISSIONAL
# - ENGENHARIA AEROESPACIAL
# - DESENHO INDUSTRIAL
# - AUTOMAÇÃO INDUSTRIAL
# - ENGENHARIA DE MATERIAIS
# - SERVIÇOS NOTARIAIS E REGISTRAIS
# - INTELIGÊNCIA ARTIFICIAL
# - GESTÃO DE INVESTIMENTOS
# - COMPUTAÇÃO EM NUVEM
# - TEATRO
# - POLÍTICAS PÚBLICAS
# - LOGÃSTICA
# - GESTÃO DE STARTUP E NOVOS NEGÓCIOS
# - E-COMMERCE
# - DESENVOLVIMENTO E GESTÃO DE STARTUPS
# - ENGENHARIA DE SOFTWARE
# - COMUNICAÇÃO DIGITAL
# - PUBLICIDADE
# - SECRETARIADO EXECUTIVO BILINGUE - PORTUGUÊS/INGLÊS
# - EMPREENDEDORISMO
# - COACHING
# - PRODUÇÃO CERVEJEIRA
#
# ==================================================
#
# =================================================================================
#   PEDIDO 2: REGISTROS ONDE CÓDIGO CINE E NOME CURSO CINE ESTÃO AUSENTES (Totalmente Desconhecidos)
# =================================================================================
# Total de registros com codigo_curso_cine E nome_cine_area_geral NaN: 5
#
# Amostra (head) dos registros. Nome do Curso Original (nome_curso) com Classificação CINE Ausente:
# 69418                                     NORMAL  SUPERIOR
# 73573    COMUNICAÇÃO SOCIAL COM HABILITAÇÃO EM PUBLICID...
# 75330                                     NORMAL  SUPERIOR
# 78181                                     NORMAL  SUPERIOR
# 81479    COMUNICAÇÃO SOCIAL COM HABILITAÇÃO EM PUBLICID...
# Name: nome_curso, dtype: object
# ==================================================

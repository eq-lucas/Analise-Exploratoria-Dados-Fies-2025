# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import IPython.display as display  # para exibir tabelas no notebook

# --- 1. Ler arquivo processado por UF ---
path_funil_uf = '../../../planilhas/processado/modulo_3/funil_e_candidatos_unicos/funil_por_uf.csv'
df = pd.read_csv(path_funil_uf)

# --- 2. Criar coluna de período (ano + semestre) ---
df['periodo'] = df['ano'].astype(str) + '.' + df['semestre'].astype(str)

# --- 3. Definir colunas e nomes curtos ---
colunas_funil = [
    'vagas_fies',
    'Inscritos_Geral',
    'inscritos_com_nota_suficiente',
    'Candidatos_Unicos_Geral',
    'candidatos_unicos_com_nota_suficiente',
    'vagas_ocupadas'
]

nomes_curto = {
    'vagas_fies': 'Vagas',
    'Inscritos_Geral': 'Inscritos',
    'inscritos_com_nota_suficiente': 'Ins. c/ Nota',
    'Candidatos_Unicos_Geral': 'Candidatos',
    'candidatos_unicos_com_nota_suficiente': 'Cand. c/ Nota',
    'vagas_ocupadas': 'Vagas Ocup.'
}

# --- 4. Variáveis básicas ---
areas = sorted(df['nome_cine_area_geral'].unique())
periodos = sorted(df['periodo'].unique())
ufs = sorted(df['uf_local_oferta'].unique())
largura_barra = 0.12
cores_ufs = plt.cm.tab20(np.linspace(0, 1, len(ufs)))  # paleta grande e distinta

# --- 5. Loop por área CINE ---
for area in areas:
    df_area = df[df['nome_cine_area_geral'] == area]

    # Agregar dados por período e UF
    df_area_grouped = (
        df_area.groupby(['periodo', 'uf_local_oferta'])[colunas_funil]
        .sum()
        .reset_index()
    )

    # Mostrar tabela antes do gráfico
    print(f"\n📊 Dados da área: {area}")
    display.display(df_area_grouped)

    # Criar gráfico
    fig, ax = plt.subplots(figsize=(18, 6))
    x = np.arange(len(colunas_funil))
    deslocamentos = np.linspace(-largura_barra * 2.5, largura_barra * 2.5, len(periodos))

    for desloc, periodo in zip(deslocamentos, periodos):
        df_periodo = df_area_grouped[df_area_grouped['periodo'] == periodo]
        base = np.zeros(len(colunas_funil))

        for cor, uf in zip(cores_ufs, ufs):
            valores = df_periodo[df_periodo['uf_local_oferta'] == uf][colunas_funil]
            if valores.empty:
                valores = [0]*len(colunas_funil)
            else:
                valores = valores.values[0]

            ax.bar(x + desloc, valores, width=largura_barra, bottom=base,
                   color=cor, label=uf if periodo == periodos[0] else "")
            base += valores

    # Configurações do gráfico
    ax.set_xticks(x)
    ax.set_xticklabels([nomes_curto[c] for c in colunas_funil], rotation=30, ha='right')
    ax.set_ylabel('Quantidade')
    ax.set_title(f'Funil FIES – {area}', fontsize=14, fontweight='bold')
    ax.grid(axis='y', linestyle='--', alpha=0.4)
    ax.legend(title='UF', bbox_to_anchor=(1.02, 1), loc='upper left', ncol=2, fontsize=7)

    plt.tight_layout()
    plt.show()

# --- 6. Gráfico Nacional (todas as áreas somadas) ---
df_total = df.groupby(['periodo', 'uf_local_oferta'])[colunas_funil].sum().reset_index()

print("\n📊 Dados Nacionais (todas as áreas):")
display.display(df_total)

fig, ax = plt.subplots(figsize=(18, 6))
x = np.arange(len(colunas_funil))
deslocamentos = np.linspace(-largura_barra * 2.5, largura_barra * 2.5, len(periodos))

for desloc, periodo in zip(deslocamentos, periodos):
    df_periodo = df_total[df_total['periodo'] == periodo]
    base = np.zeros(len(colunas_funil))

    for cor, uf in zip(cores_ufs, ufs):
        valores = df_periodo[df_periodo['uf_local_oferta'] == uf][colunas_funil]
        if valores.empty:
            valores = [0]*len(colunas_funil)
        else:
            valores = valores.values[0]

        ax.bar(x + desloc, valores, width=largura_barra, bottom=base,
               color=cor, label=uf if periodo == periodos[0] else "")
        base += valores

ax.set_xticks(x)
ax.set_xticklabels([nomes_curto[c] for c in colunas_funil], rotation=30, ha='right')
ax.set_ylabel('Quantidade')
ax.set_title('Funil FIES – Nacional (Todas as Áreas, por UF)', fontsize=14, fontweight='bold')
ax.grid(axis='y', linestyle='--', alpha=0.4)
ax.legend(title='UF', bbox_to_anchor=(1.02, 1), loc='upper left', ncol=2, fontsize=7)

plt.tight_layout()
plt.show()
# Out:
# 📊 Dados da área: Agricultura, silvicultura, pesca e veterinária
#         periodo uf_local_oferta  vagas_fies  Inscritos_Geral  \
# 0    2019.0.1.0              AL       220.0            146.0
# 1    2019.0.1.0              AM       216.0            712.0
# 2    2019.0.1.0              BA      1898.0           1432.0
# 3    2019.0.1.0              CE       399.0           1168.0
# 4    2019.0.1.0              DF       267.0            627.0
# ..          ...             ...         ...              ...
# 142  2021.0.2.0              RS       308.0            431.0
# 143  2021.0.2.0              SC       463.0            145.0
# 144  2021.0.2.0              SE       156.0             77.0
# 145  2021.0.2.0              SP      3452.0           1911.0
# 146  2021.0.2.0              TO       148.0            134.0
#
#      inscritos_com_nota_suficiente  Candidatos_Unicos_Geral  \
# 0                            100.0                    102.0
# 1                            203.0                    310.0
# 2                            618.0                    866.0
# 3                            361.0                    726.0
# 4                             91.0                    350.0
# ..                             ...                      ...
# 142                          179.0                    263.0
# 143                           77.0                     86.0
# 144                           46.0                     45.0
# 145                          614.0                   1009.0
# 146                           88.0                    115.0
#
#      candidatos_unicos_com_nota_suficiente  vagas_ocupadas
# 0                                     72.0            39.0
# 1                                     84.0            51.0
# 2                                    404.0           274.0
# 3                                    236.0           147.0
# 4                                     67.0            39.0
# ..                                     ...             ...
# 142                                  116.0            95.0
# 143                                   45.0            27.0
# 144                                   26.0            19.0
# 145                                  337.0           370.0
# 146                                   71.0            50.0
#
# [147 rows x 8 columns]
# 📊 Dados da área: Artes e humanidades
#         periodo uf_local_oferta  vagas_fies  Inscritos_Geral  \
# 0    2019.0.1.0              AL       325.0             41.0
# 1    2019.0.1.0              AM       589.0            305.0
# 2    2019.0.1.0              AP        40.0             25.0
# 3    2019.0.1.0              BA      1726.0            432.0
# 4    2019.0.1.0              CE      1588.0            543.0
# ..          ...             ...         ...              ...
# 143  2021.0.2.0              RR        40.0              0.0
# 144  2021.0.2.0              RS       377.0             26.0
# 145  2021.0.2.0              SC       297.0             11.0
# 146  2021.0.2.0              SE       227.0              9.0
# 147  2021.0.2.0              SP      7747.0            499.0
#
#      inscritos_com_nota_suficiente  Candidatos_Unicos_Geral  \
# 0                             26.0                     23.0
# 1                            159.0                    147.0
# 2                             25.0                     15.0
# 3                            234.0                    223.0
# 4                            277.0                    276.0
# ..                             ...                      ...
# 143                            0.0                      0.0
# 144                           13.0                     19.0
# 145                           11.0                     10.0
# 146                            9.0                      8.0
# 147                          384.0                    255.0
#
#      candidatos_unicos_com_nota_suficiente  vagas_ocupadas
# 0                                     16.0             4.0
# 1                                     86.0            22.0
# 2                                     15.0             7.0
# 3                                    132.0            51.0
# 4                                    163.0            47.0
# ..                                     ...             ...
# 143                                    0.0             0.0
# 144                                   12.0             4.0
# 145                                   10.0             1.0
# 146                                    8.0             4.0
# 147                                  198.0            69.0
#
# [148 rows x 8 columns]
# 📊 Dados da área: Ciências naturais, matemática e estatística
#        periodo uf_local_oferta  vagas_fies  Inscritos_Geral  \
# 0   2019.0.1.0              AL        60.0             26.0
# 1   2019.0.1.0              AM        99.0             88.0
# 2   2019.0.1.0              BA       400.0            128.0
# 3   2019.0.1.0              CE        96.0             96.0
# 4   2019.0.1.0              DF       534.0            248.0
# ..         ...             ...         ...              ...
# 88  2021.0.2.0              PR        70.0             14.0
# 89  2021.0.2.0              RJ       278.0             57.0
# 90  2021.0.2.0              RS       119.0             20.0
# 91  2021.0.2.0              SC       114.0              1.0
# 92  2021.0.2.0              SP      2630.0            212.0
#
#     inscritos_com_nota_suficiente  Candidatos_Unicos_Geral  \
# 0                             4.0                     11.0
# 1                            16.0                     44.0
# 2                            59.0                     53.0
# 3                            46.0                     48.0
# 4                            74.0                    113.0
# ..                            ...                      ...
# 88                           12.0                      7.0
# 89                           30.0                     24.0
# 90                           13.0                     11.0
# 91                            1.0                      1.0
# 92                          137.0                     88.0
#
#     candidatos_unicos_com_nota_suficiente  vagas_ocupadas
# 0                                     1.0             1.0
# 1                                     5.0             1.0
# 2                                    27.0             5.0
# 3                                    26.0             5.0
# 4                                    38.0             5.0
# ..                                    ...             ...
# 88                                    6.0             2.0
# 89                                   15.0             6.0
# 90                                    9.0             1.0
# 91                                    1.0             1.0
# 92                                   65.0            16.0
#
# [93 rows x 8 columns]
# 📊 Dados da área: Ciências sociais, comunicação e informação
#         periodo uf_local_oferta  vagas_fies  Inscritos_Geral  \
# 0    2019.0.1.0              AC       110.0            213.0
# 1    2019.0.1.0              AL       694.0            633.0
# 2    2019.0.1.0              AM      1269.0           1020.0
# 3    2019.0.1.0              AP       152.0            294.0
# 4    2019.0.1.0              BA      3549.0           3636.0
# ..          ...             ...         ...              ...
# 157  2021.0.2.0              RS      1490.0            662.0
# 158  2021.0.2.0              SC      1081.0            183.0
# 159  2021.0.2.0              SE       284.0            206.0
# 160  2021.0.2.0              SP     16342.0           2631.0
# 161  2021.0.2.0              TO       157.0            191.0
#
#      inscritos_com_nota_suficiente  Candidatos_Unicos_Geral  \
# 0                             65.0                    101.0
# 1                            148.0                    320.0
# 2                            201.0                    440.0
# 3                             96.0                    178.0
# 4                            826.0                   1764.0
# ..                             ...                      ...
# 157                          211.0                    354.0
# 158                          101.0                     95.0
# 159                           71.0                     93.0
# 160                         1066.0                   1290.0
# 161                          106.0                    105.0
#
#      candidatos_unicos_com_nota_suficiente  vagas_ocupadas
# 0                                     30.0            11.0
# 1                                     90.0            56.0
# 2                                     94.0            55.0
# 3                                     60.0            19.0
# 4                                    444.0           311.0
# ..                                     ...             ...
# 157                                  125.0           111.0
# 158                                   56.0            17.0
# 159                                   38.0            28.0
# 160                                  533.0           334.0
# 161                                   57.0            40.0
#
# [162 rows x 8 columns]
# 📊 Dados da área: Computação e Tecnologias da Informação e Comunicação (TIC)
#         periodo uf_local_oferta  vagas_fies  Inscritos_Geral  \
# 0    2019.0.1.0              AC       276.0            111.0
# 1    2019.0.1.0              AL       790.0            158.0
# 2    2019.0.1.0              AM      1150.0            795.0
# 3    2019.0.1.0              AP       254.0            211.0
# 4    2019.0.1.0              BA      3062.0            989.0
# ..          ...             ...         ...              ...
# 157  2021.0.2.0              RS      1163.0            166.0
# 158  2021.0.2.0              SC       615.0             39.0
# 159  2021.0.2.0              SE       470.0             59.0
# 160  2021.0.2.0              SP     15465.0           1005.0
# 161  2021.0.2.0              TO        98.0             17.0
#
#      inscritos_com_nota_suficiente  Candidatos_Unicos_Geral  \
# 0                            111.0                     47.0
# 1                             97.0                     71.0
# 2                            483.0                    315.0
# 3                            109.0                     83.0
# 4                            687.0                    463.0
# ..                             ...                      ...
# 157                          150.0                     83.0
# 158                           34.0                     26.0
# 159                           59.0                     34.0
# 160                          882.0                    445.0
# 161                           12.0                     17.0
#
#      candidatos_unicos_com_nota_suficiente  vagas_ocupadas
# 0                                     47.0            12.0
# 1                                     43.0             5.0
# 2                                    194.0            57.0
# 3                                     43.0             5.0
# 4                                    340.0            89.0
# ..                                     ...             ...
# 157                                   77.0            26.0
# 158                                   21.0             4.0
# 159                                   34.0             8.0
# 160                                  386.0            83.0
# 161                                   12.0             4.0
#
# [162 rows x 8 columns]
# 📊 Dados da área: Educação
#         periodo uf_local_oferta  vagas_fies  Inscritos_Geral  \
# 0    2019.0.1.0              AC       150.0             80.0
# 1    2019.0.1.0              AL       863.0            386.0
# 2    2019.0.1.0              AM      2428.0           1485.0
# 3    2019.0.1.0              AP       432.0            531.0
# 4    2019.0.1.0              BA      5889.0           2274.0
# ..          ...             ...         ...              ...
# 156  2021.0.2.0              RS      1182.0             96.0
# 157  2021.0.2.0              SC       299.0              8.0
# 158  2021.0.2.0              SE       864.0             91.0
# 159  2021.0.2.0              SP     17567.0            668.0
# 160  2021.0.2.0              TO       165.0              7.0
#
#      inscritos_com_nota_suficiente  Candidatos_Unicos_Geral  \
# 0                             32.0                     80.0
# 1                            136.0                    193.0
# 2                            323.0                    672.0
# 3                             92.0                    260.0
# 4                            633.0                   1091.0
# ..                             ...                      ...
# 156                           56.0                     66.0
# 157                            8.0                      6.0
# 158                           64.0                     43.0
# 159                          349.0                    330.0
# 160                            7.0                      6.0
#
#      candidatos_unicos_com_nota_suficiente  vagas_ocupadas
# 0                                     32.0             6.0
# 1                                     85.0            17.0
# 2                                    157.0            51.0
# 3                                     52.0            14.0
# 4                                    366.0           116.0
# ..                                     ...             ...
# 156                                   41.0            13.0
# 157                                    6.0             1.0
# 158                                   33.0             5.0
# 159                                  185.0            71.0
# 160                                    6.0             2.0
#
# [161 rows x 8 columns]
# 📊 Dados da área: Engenharia, produção e construção
#         periodo uf_local_oferta  vagas_fies  Inscritos_Geral  \
# 0    2019.0.1.0              AC       392.0            358.0
# 1    2019.0.1.0              AL      2087.0            792.0
# 2    2019.0.1.0              AM      4406.0           2505.0
# 3    2019.0.1.0              AP       495.0            473.0
# 4    2019.0.1.0              BA     14123.0           5660.0
# ..          ...             ...         ...              ...
# 157  2021.0.2.0              RS      3503.0            368.0
# 158  2021.0.2.0              SC      2327.0            193.0
# 159  2021.0.2.0              SE      1190.0            128.0
# 160  2021.0.2.0              SP     35163.0           2464.0
# 161  2021.0.2.0              TO       245.0             85.0
#
#      inscritos_com_nota_suficiente  Candidatos_Unicos_Geral  \
# 0                            109.0                    171.0
# 1                            442.0                    398.0
# 2                            916.0                   1094.0
# 3                            181.0                    229.0
# 4                           2301.0                   2718.0
# ..                             ...                      ...
# 157                          266.0                    218.0
# 158                          108.0                    108.0
# 159                           91.0                     66.0
# 160                         1654.0                   1205.0
# 161                           68.0                     48.0
#
#      candidatos_unicos_com_nota_suficiente  vagas_ocupadas
# 0                                     61.0            37.0
# 1                                    225.0            99.0
# 2                                    427.0           195.0
# 3                                     98.0            45.0
# 4                                   1180.0           697.0
# ..                                     ...             ...
# 157                                  169.0            60.0
# 158                                   64.0            17.0
# 159                                   49.0            20.0
# 160                                  825.0           340.0
# 161                                   38.0            11.0
#
# [162 rows x 8 columns]
# 📊 Dados da área: Negócios, administração e direito
#         periodo uf_local_oferta  vagas_fies  Inscritos_Geral  \
# 0    2019.0.1.0              AC       683.0           1459.0
# 1    2019.0.1.0              AL      3262.0           2419.0
# 2    2019.0.1.0              AM      7022.0           6059.0
# 3    2019.0.1.0              AP      1136.0           2113.0
# 4    2019.0.1.0              BA     19377.0          14089.0
# ..          ...             ...         ...              ...
# 157  2021.0.2.0              RS      7243.0           1734.0
# 158  2021.0.2.0              SC      4826.0            421.0
# 159  2021.0.2.0              SE      1961.0            583.0
# 160  2021.0.2.0              SP     76759.0           5961.0
# 161  2021.0.2.0              TO      1080.0            634.0
#
#      inscritos_com_nota_suficiente  Candidatos_Unicos_Geral  \
# 0                            187.0                    645.0
# 1                            512.0                   1108.0
# 2                            975.0                   2466.0
# 3                            335.0                    857.0
# 4                           2669.0                   6411.0
# ..                             ...                      ...
# 157                          499.0                    868.0
# 158                          213.0                    198.0
# 159                          273.0                    277.0
# 160                         2463.0                   2724.0
# 161                          227.0                    270.0
#
#      candidatos_unicos_com_nota_suficiente  vagas_ocupadas
# 0                                    101.0            54.0
# 1                                    246.0           162.0
# 2                                    425.0           309.0
# 3                                    137.0            64.0
# 4                                   1324.0          1061.0
# ..                                     ...             ...
# 157                                  270.0           262.0
# 158                                  107.0            41.0
# 159                                  137.0            77.0
# 160                                 1160.0           727.0
# 161                                  108.0           109.0
#
# [162 rows x 8 columns]
# 📊 Dados da área: Saúde e bem-estar
#         periodo uf_local_oferta  vagas_fies  Inscritos_Geral  \
# 0    2019.0.1.0              AC       787.0           1515.0
# 1    2019.0.1.0              AL      2973.0           5199.0
# 2    2019.0.1.0              AM      5357.0           7776.0
# 3    2019.0.1.0              AP       523.0           2115.0
# 4    2019.0.1.0              BA     18846.0          26199.0
# ..          ...             ...         ...              ...
# 157  2021.0.2.0              RS      3375.0           2582.0
# 158  2021.0.2.0              SC      2715.0           1167.0
# 159  2021.0.2.0              SE      1981.0           1949.0
# 160  2021.0.2.0              SP     44428.0          18156.0
# 161  2021.0.2.0              TO       767.0           2029.0
#
#      inscritos_com_nota_suficiente  Candidatos_Unicos_Geral  \
# 0                            328.0                    774.0
# 1                           2506.0                   2633.0
# 2                           1842.0                   3581.0
# 3                            552.0                    926.0
# 4                           6039.0                  13480.0
# ..                             ...                      ...
# 157                         1376.0                   1566.0
# 158                          555.0                    782.0
# 159                          587.0                   1231.0
# 160                         4566.0                   9791.0
# 161                          311.0                   1090.0
#
#      candidatos_unicos_com_nota_suficiente  vagas_ocupadas
# 0                                    205.0           186.0
# 1                                   1449.0           445.0
# 2                                    765.0           452.0
# 3                                    285.0           134.0
# 4                                   3069.0          2248.0
# ..                                     ...             ...
# 157                                  753.0           343.0
# 158                                  299.0           109.0
# 159                                  297.0           225.0
# 160                                 2304.0          1263.0
# 161                                  180.0           131.0
#
# [162 rows x 8 columns]
# 📊 Dados da área: Serviços
#         periodo uf_local_oferta  vagas_fies  Inscritos_Geral  \
# 0    2019.0.1.0              AC        60.0             41.0
# 1    2019.0.1.0              AL       553.0             96.0
# 2    2019.0.1.0              AM      1283.0            541.0
# 3    2019.0.1.0              AP        25.0              0.0
# 4    2019.0.1.0              BA      2897.0            963.0
# ..          ...             ...         ...              ...
# 146  2021.0.2.0              RS       446.0             36.0
# 147  2021.0.2.0              SC       490.0             13.0
# 148  2021.0.2.0              SE       242.0             26.0
# 149  2021.0.2.0              SP      5556.0            288.0
# 150  2021.0.2.0              TO       105.0             13.0
#
#      inscritos_com_nota_suficiente  Candidatos_Unicos_Geral  \
# 0                             41.0                     41.0
# 1                             57.0                     49.0
# 2                            284.0                    231.0
# 3                              0.0                      0.0
# 4                            544.0                    439.0
# ..                             ...                      ...
# 146                           32.0                     26.0
# 147                           13.0                      9.0
# 148                           12.0                     17.0
# 149                          278.0                    144.0
# 150                           13.0                     10.0
#
#      candidatos_unicos_com_nota_suficiente  vagas_ocupadas
# 0                                     41.0            17.0
# 1                                     31.0             9.0
# 2                                    126.0            41.0
# 3                                      0.0             0.0
# 4                                    265.0            82.0
# ..                                     ...             ...
# 146                                   24.0             5.0
# 147                                    9.0             0.0
# 148                                    9.0             2.0
# 149                                  138.0            28.0
# 150                                   10.0             3.0
#
# [151 rows x 8 columns]
# 📊 Dados Nacionais (todas as áreas):
#         periodo uf_local_oferta  vagas_fies  Inscritos_Geral  \
# 0    2019.0.1.0              AC      2458.0           3777.0
# 1    2019.0.1.0              AL     11827.0           9896.0
# 2    2019.0.1.0              AM     23819.0          21286.0
# 3    2019.0.1.0              AP      3057.0           5762.0
# 4    2019.0.1.0              BA     71767.0          55802.0
# ..          ...             ...         ...              ...
# 157  2021.0.2.0              RS     19206.0           6121.0
# 158  2021.0.2.0              SC     13227.0           2181.0
# 159  2021.0.2.0              SE      7375.0           3128.0
# 160  2021.0.2.0              SP    225109.0          33795.0
# 161  2021.0.2.0              TO      2765.0           3110.0
#
#      inscritos_com_nota_suficiente  Candidatos_Unicos_Geral  \
# 0                            873.0                   1859.0
# 1                           4028.0                   4908.0
# 2                           5402.0                   9300.0
# 3                           1390.0                   2548.0
# 4                          14610.0                  27508.0
# ..                             ...                      ...
# 157                         2795.0                   3474.0
# 158                         1121.0                   1321.0
# 159                         1212.0                   1814.0
# 160                        12393.0                  17281.0
# 161                          832.0                   1661.0
#
#      candidatos_unicos_com_nota_suficiente  vagas_ocupadas
# 0                                    517.0           323.0
# 1                                   2258.0           837.0
# 2                                   2363.0          1234.0
# 3                                    690.0           288.0
# 4                                   7551.0          4934.0
# ..                                     ...             ...
# 157                                 1596.0           920.0
# 158                                  618.0           218.0
# 159                                  631.0           388.0
# 160                                 6131.0          3301.0
# 161                                  482.0           350.0
#
# [162 rows x 8 columns]

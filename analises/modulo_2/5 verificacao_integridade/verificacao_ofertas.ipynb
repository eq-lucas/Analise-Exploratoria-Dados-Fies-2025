# %%
import pandas as pd
import os

path='../../../planilhas/limpo/modulo_2/ajustar_nan_cine_ofertas/ofertas_agrupado_limpo_CORRIGIDO.csv'


PK = [
'codigo_e_mec_mantenedora_ofertas',
'codigo_local_oferta_ofertas',
'codigo_grupo_preferencia_ofertas',
'codigo_curso_ofertas',
'turno_ofertas',
]

df_limpo= pd.read_csv(path)

print(df_limpo.shape)

qtde_linhas_antes= df_limpo.shape[0]

df_agrupando_por_pk= df_limpo.groupby(by=PK,as_index=False).count()

qtde_linhas_depois= df_agrupando_por_pk.shape[0]

print(f'antes : {qtde_linhas_antes}')
print(f'depois: {qtde_linhas_depois}')

if qtde_linhas_antes != qtde_linhas_depois:

    print('\nERRO PROVAVEL DUPLICAÇÃO DE LINHA: ')
    
    filtro= df_limpo.duplicated(subset=df_limpo.columns.to_list(),keep='first')

    linhas_duplicadas= df_limpo[filtro].shape[0]

    print(f'Total de linhas duplicadas: {linhas_duplicadas}\n')

    if linhas_duplicadas == 0:

        print('ERRO PROVAVEL LINHA VAZIA:')

        df_sem_linha_vazia= df_limpo.dropna(subset=df_limpo.columns.to_list(),how='all')

        qtde_linhas_antes= df_sem_linha_vazia.shape[0]

        df_agrupando_por_pk= df_limpo.groupby(by=PK,as_index=False).count()

        qtde_linhas_depois= df_agrupando_por_pk.shape[0]

        print(f'\nantes : {qtde_linhas_antes}')
        print(f'depois: {qtde_linhas_depois}\n')


# --- Bloco de Verificação de Colunas ---
print("\n--- Verificando Nomes e Total de Colunas ---")

# Pega a lista de colunas
lista_colunas = df_limpo.columns.to_list()
total_colunas = len(lista_colunas)

print(f"Total de colunas: {total_colunas}\n")
print("Nomes das colunas:")

# Imprime uma por linha para facilitar a leitura
for coluna in lista_colunas:
    print(coluna)

print("--- Fim da Verificação de Colunas ---")
# Out:
# <ipython-input-1-b19bd3ca9a94>:16: DtypeWarning: Columns (31,33,34,35,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_limpo= pd.read_csv(path)
# (143622, 69)
# antes : 143622
# depois: 143622
#
# --- Verificando Nomes e Total de Colunas ---
# Total de colunas: 69
#
# Nomes das colunas:
# ano_ofertas
# semestre_ofertas
# nome_mantenedora_ofertas
# codigo_e_mec_mantenedora_ofertas
# cnpj_mantenedora_ofertas
# nome_ies_ofertas
# codigo_e_mec_ies_ofertas
# organizacao_academica_ies_ofertas
# uf_ies_ofertas
# municipio_ies_ofertas
# nome_local_oferta_ofertas
# codigo_local_oferta_ofertas
# municipio_local_oferta_ofertas
# uf_local_oferta_ofertas
# nome_microrregiao_ofertas
# codigo_microrregiao_ofertas
# codigo_mesorregiao_ofertas
# nome_mesorregiao_ofertas
# area_conhecimento_ofertas
# subarea_conhecimento_ofertas
# codigo_grupo_preferencia_ofertas
# nota_corte_grupo_preferencia_ofertas
# codigo_curso_ofertas
# nome_curso_ofertas
# turno_ofertas
# grau_ofertas
# conceito_ofertas
# vagas_autorizadas_e_mec_ofertas
# vagas_ofertadas_fies_ofertas
# vagas_alem_da_oferta_ofertas
# vagas_ocupadas_ofertas
# participa_p_fies_ofertas
# vagas_ofertadas_p_fies_ofertas
# banco_nordeste_brasil_004_ofertas
# itau_unibanco_pravaler_341_ofertas
# bv_financeira_pravaler_455_ofertas
# banco_andbank_pravaler_65_ofertas
# banco_amazonia_sa_003_ofertas
# valor_bruto_curso_ofertas
# semestre_1_bruto_ofertas
# semestre_2_bruto_ofertas
# semestre_3_bruto_ofertas
# semestre_4_bruto_ofertas
# semestre_5_bruto_ofertas
# semestre_6_bruto_ofertas
# semestre_7_bruto_ofertas
# semestre_8_bruto_ofertas
# semestre_9_bruto_ofertas
# semestre_10_bruto_ofertas
# semestre_11_bruto_ofertas
# semestre_12_bruto_ofertas
# valor_curso_fies_ofertas
# indice_correcao_ipca_ofertas
# semestre_1_fies_ofertas
# semestre_2_fies_ofertas
# semestre_3_fies_ofertas
# semestre_4_fies_ofertas
# semestre_5_fies_ofertas
# semestre_6_fies_ofertas
# semestre_7_fies_ofertas
# semestre_8_fies_ofertas
# semestre_9_fies_ofertas
# semestre_10_fies_ofertas
# semestre_11_fies_ofertas
# semestre_12_fies_ofertas
# NO_CURSO
# CO_CURSO
# CO_CINE_AREA_GERAL
# NO_CINE_AREA_GERAL
# --- Fim da Verificação de Colunas ---

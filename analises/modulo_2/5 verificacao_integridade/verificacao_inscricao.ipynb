# %%
import pandas as pd
import os

path='../../../planilhas/limpo/modulo_2/inscritos_coluna_filtro_renda_regiao/1 inscritos_coluna_passou_peneira_renda.csv'


PK= [
'id_estudante_inscricao',
'opcoes_cursos_inscricao_inscricao'
]

df_limpo= pd.read_csv(path)

print(df_limpo.shape)

qtde_linhas_antes= df_limpo.shape[0]

df_agrupando_por_pk= df_limpo.groupby(by=PK,as_index=False).count()

qtde_linhas_depois= df_agrupando_por_pk.shape[0]

print(f'antes : {qtde_linhas_antes}')
print(f'depois: {qtde_linhas_depois}')

if qtde_linhas_antes != qtde_linhas_depois:

    print('\nERRO PROVAVEL DUPLICAÇÃO DE LINHA: ')
    
    filtro= df_limpo.duplicated(subset=df_limpo.columns.to_list(),keep='first')

    linhas_duplicadas= df_limpo[filtro].shape[0]

    print(f'Total de linhas duplicadas: {linhas_duplicadas}\n')

    if linhas_duplicadas == 0:

        print('ERRO PROVAVEL LINHA VAZIA:')

        df_sem_linha_vazia= df_limpo.dropna(subset=df_limpo.columns.to_list(),how='all')

        qtde_linhas_antes= df_sem_linha_vazia.shape[0]

        df_agrupando_por_pk= df_limpo.groupby(by=PK,as_index=False).count()

        qtde_linhas_depois= df_agrupando_por_pk.shape[0]

        print(f'\nantes : {qtde_linhas_antes}')
        print(f'depois: {qtde_linhas_depois}\n')


# --- Bloco de Verificação de Colunas ---
print("\n--- Verificando Nomes e Total de Colunas ---")

# Pega a lista de colunas
lista_colunas = df_limpo.columns.to_list()
total_colunas = len(lista_colunas)

print(f"Total de colunas: {total_colunas}\n")
print("Nomes das colunas:")

# Imprime uma por linha para facilitar a leitura
for coluna in lista_colunas:
    print(coluna)

print("--- Fim da Verificação de Colunas ---")
# Out:
# <ipython-input-1-28ff02e5a4de>:13: DtypeWarning: Columns (25,37,38,47,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_limpo= pd.read_csv(path)
# (2197234, 65)
# antes : 2197234
# depois: 2197234
#
# --- Verificando Nomes e Total de Colunas ---
# Total de colunas: 65
#
# Nomes das colunas:
# ano_processo_seletivo_inscricao
# semestre_processo_seletivo_inscricao
# codigo_grupo_preferencia_inscricao
# classificacao_inscricao
# id_estudante_inscricao
# sexo_inscricao
# data_nascimento_inscricao
# uf_residencia_inscricao
# municipio_residencia_inscricao
# etnia_cor_inscricao
# pessoa_com_deficiencia_inscricao
# concluiu_ensino_medio_escola_publica_inscricao
# ano_conclusao_ensino_medio_inscricao
# concluiu_curso_superior_inscricao
# beneficiado_creduc_ou_fies_inscricao
# professor_rede_publica_ensino_inscricao
# numero_membros_grupo_familiar_inscricao
# renda_familiar_mensal_bruta_inscricao
# renda_mensal_bruta_per_capita_inscricao
# regiao_grupo_preferencia_inscricao
# uf_grupo_preferencia_inscricao
# codigo_microrregiao_inscricao
# microrregiao_inscricao
# codigo_mesorregiao_inscricao
# mesorregiao_inscricao
# conceito_curso_gp_inscricao
# area_conhecimento_inscricao
# subarea_conhecimento_inscricao
# nota_corte_grupo_preferencia_inscricao
# opcoes_cursos_inscricao_inscricao
# nome_mantenedora_inscricao
# natureza_juridica_mantenedora_inscricao
# cnpj_mantenedora_inscricao
# codigo_e_mec_mantenedora_inscricao
# nome_ies_inscricao
# codigo_e_mec_ies_inscricao
# organizacao_academica_ies_inscricao
# municipio_ies_inscricao
# uf_ies_inscricao
# nome_local_oferta_inscricao
# codigo_local_oferta_inscricao
# municipio_local_oferta_inscricao
# uf_local_oferta_inscricao
# codigo_curso_inscricao
# nome_curso_inscricao
# turno_inscricao
# grau_inscricao
# conceito_curso_inscricao
# media_nota_enem_inscricao
# ano_enem_inscricao
# nota_redacao_inscricao
# nota_matematica_inscricao
# nota_linguagens_inscricao
# nota_ciencias_natureza_inscricao
# nota_ciencias_humanas_inscricao
# situacao_inscricao_fies_inscricao
# percentual_financiamento_inscricao
# semestre_financiamento_inscricao
# qtde_semestre_financiado_inscricao
# NO_CURSO
# CO_CURSO
# CO_CINE_AREA_GERAL
# NO_CINE_AREA_GERAL
# regiao_residencia
# modalidade_fies
# --- Fim da Verificação de Colunas ---

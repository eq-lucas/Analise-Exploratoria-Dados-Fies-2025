# %% [markdown]
# Connected to venv (Python 3.12.3)

# %%
import pandas as pd
import os

# --- 1. Configuração ---
pd.set_option('display.max_rows', None) # Para mostrar todas as áreas
pd.set_option('display.max_columns', None)

# Caminho para os arquivos que seu script anterior GEROU
path_leitura = '../../../planilhas/limpo/modulo_1/ofertas_coluna_CINE/'

# Coluna que você quer analisar
coluna_para_analisar = 'NO_CINE_AREA_GERAL' 

# --- 2. Verificar o diretório ---
print(f"Iniciando leitura dos arquivos em: {path_leitura}\n")

if not os.path.exists(path_leitura):
    print(f"ERRO: O diretório não existe: {path_leitura}")
else:
    try:
        lista_nomes_arquivos = os.listdir(path_leitura)
        # Ordenar a lista ajuda a ver os resultados em ordem cronológica
        lista_nomes_arquivos.sort() 
    except Exception as e:
        print(f"ERRO ao ler o diretório: {e}")
        lista_nomes_arquivos = []

    if not lista_nomes_arquivos:
        print("Nenhum arquivo encontrado no diretório.")

    # --- 3. Loop de Análise Individual ---
    for arquivo in lista_nomes_arquivos:
        
        if arquivo.endswith('.csv'):
            caminho_completo = os.path.join(path_leitura, arquivo)
            
            # Imprime um cabeçalho para cada arquivo
            print(f"\n{'='*80}")
            print(f"--- Iniciando Análise do Arquivo: {arquivo} ---")
            print(f"{'='*80}")
            
            try:
                # Lê o dataframe individual
                df_temp = pd.read_csv(caminho_completo, low_memory=False)
                
                # Verifica se a coluna de análise realmente existe neste arquivo
                if coluna_para_analisar not in df_temp.columns:
                    print(f"  ERRO: A coluna '{coluna_para_analisar}' não foi encontrada neste arquivo!")
                    print(f"  Colunas disponíveis: {df_temp.columns.to_list()}")
                else:
                    # --- 4. Executar o "Group By + Count" (com value_counts) ---
                    print(f"\n  Contagem de valores para '{coluna_para_analisar}':")
                    
                    # value_counts(dropna=False) faz o groupby+count, INCLUINDO NaNs
                    contagem = df_temp[coluna_para_analisar].value_counts(dropna=False)
                    
                    # Imprime a contagem
                    print(contagem)

                    # --- 5. Resumo explícito dos NaNs para ESTE arquivo ---
                    print("\n  --- Resumo dos NaNs (para este arquivo) ---")
                    
                    total_linhas = len(df_temp)
                    total_nans = df_temp[coluna_para_analisar].isnull().sum()
                    
                    if total_linhas > 0:
                        percentual_nans = (total_nans / total_linhas) * 100
                        print(f"  Total de ofertas (linhas): {total_linhas}")
                        print(f"  Total de NaNs (cursos não encontrados): {total_nans}")
                        print(f"  Percentual de NaNs: {percentual_nans:.2f}%")
                    else:
                        print("  Arquivo está vazio.")
                        
            except Exception as e:
                print(f"  *** ERRO GERAL ao processar o arquivo {arquivo}: {e} ***")

    print(f"\n{'='*80}")
    print("--- Análise individual de todos os arquivos concluída. ---")
    print(f"{'='*80}")
# Out:
# Iniciando leitura dos arquivos em: ../../../planilhas/limpo/modulo_1/ofertas_coluna_CINE/
#
#
# ================================================================================
# --- Iniciando Análise do Arquivo: fies_1_ofertas_2019_limpo_cine.csv ---
# ================================================================================
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Negócios, administração e direito                             7059
# Saúde e bem-estar                                             5878
# Engenharia, produção e construção                             4371
# NaN                                                           3495
# Educação                                                      2154
# Computação e Tecnologias da Informação e Comunicação (TIC)    1493
# Ciências sociais, comunicação e informação                    1423
# Serviços                                                       862
# Artes e humanidades                                            694
# Agricultura, silvicultura, pesca e veterinária                 547
# Ciências naturais, matemática e estatística                    181
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este arquivo) ---
#   Total de ofertas (linhas): 28157
#   Total de NaNs (cursos não encontrados): 3495
#   Percentual de NaNs: 12.41%
#
# ================================================================================
# --- Iniciando Análise do Arquivo: fies_1_ofertas_2020_limpo_cine.csv ---
# ================================================================================
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Negócios, administração e direito                             6399
# Saúde e bem-estar                                             5840
# Engenharia, produção e construção                             3845
# NaN                                                           1746
# Educação                                                      1714
# Ciências sociais, comunicação e informação                    1531
# Computação e Tecnologias da Informação e Comunicação (TIC)    1337
# Serviços                                                       827
# Artes e humanidades                                            649
# Agricultura, silvicultura, pesca e veterinária                 612
# Ciências naturais, matemática e estatística                    167
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este arquivo) ---
#   Total de ofertas (linhas): 24667
#   Total de NaNs (cursos não encontrados): 1746
#   Percentual de NaNs: 7.08%
#
# ================================================================================
# --- Iniciando Análise do Arquivo: fies_1_ofertas_2021_limpo_cine.csv ---
# ================================================================================
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Negócios, administração e direito                             6324
# Saúde e bem-estar                                             5832
# Engenharia, produção e construção                             3295
# Ciências sociais, comunicação e informação                    1615
# NaN                                                           1589
# Educação                                                      1398
# Computação e Tecnologias da Informação e Comunicação (TIC)    1292
# Serviços                                                       695
# Agricultura, silvicultura, pesca e veterinária                 667
# Artes e humanidades                                            610
# Ciências naturais, matemática e estatística                    146
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este arquivo) ---
#   Total de ofertas (linhas): 23463
#   Total de NaNs (cursos não encontrados): 1589
#   Percentual de NaNs: 6.77%
#
# ================================================================================
# --- Iniciando Análise do Arquivo: fies_2_ofertas_2019_limpo_cine.csv ---
# ================================================================================
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Negócios, administração e direito                             5968
# Saúde e bem-estar                                             5168
# Engenharia, produção e construção                             3689
# NaN                                                           1495
# Educação                                                      1493
# Ciências sociais, comunicação e informação                    1264
# Computação e Tecnologias da Informação e Comunicação (TIC)    1143
# Serviços                                                       675
# Artes e humanidades                                            572
# Agricultura, silvicultura, pesca e veterinária                 461
# Ciências naturais, matemática e estatística                    131
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este arquivo) ---
#   Total de ofertas (linhas): 22059
#   Total de NaNs (cursos não encontrados): 1495
#   Percentual de NaNs: 6.78%
#
# ================================================================================
# --- Iniciando Análise do Arquivo: fies_2_ofertas_2020_limpo_cine.csv ---
# ================================================================================
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Negócios, administração e direito                             5988
# Saúde e bem-estar                                             5481
# Engenharia, produção e construção                             3195
# Ciências sociais, comunicação e informação                    1448
# NaN                                                           1425
# Educação                                                      1269
# Computação e Tecnologias da Informação e Comunicação (TIC)    1214
# Serviços                                                       691
# Artes e humanidades                                            569
# Agricultura, silvicultura, pesca e veterinária                 556
# Ciências naturais, matemática e estatística                    120
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este arquivo) ---
#   Total de ofertas (linhas): 21956
#   Total de NaNs (cursos não encontrados): 1425
#   Percentual de NaNs: 6.49%
#
# ================================================================================
# --- Iniciando Análise do Arquivo: fies_2_ofertas_2021_limpo_cine.csv ---
# ================================================================================
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Negócios, administração e direito                             6134
# Saúde e bem-estar                                             6013
# Engenharia, produção e construção                             3364
# Ciências sociais, comunicação e informação                    1603
# Educação                                                      1519
# Computação e Tecnologias da Informação e Comunicação (TIC)    1293
# NaN                                                           1218
# Serviços                                                       722
# Artes e humanidades                                            670
# Agricultura, silvicultura, pesca e veterinária                 649
# Ciências naturais, matemática e estatística                    135
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este arquivo) ---
#   Total de ofertas (linhas): 23320
#   Total de NaNs (cursos não encontrados): 1218
#   Percentual de NaNs: 5.22%
#
# ================================================================================
# --- Análise individual de todos os arquivos concluída. ---
# ================================================================================

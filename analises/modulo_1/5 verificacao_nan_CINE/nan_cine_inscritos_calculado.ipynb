# %%
import pandas as pd
import os

# --- 1. Configuração ---
pd.set_option('display.max_rows', None) # Para mostrar todas as áreas
pd.set_option('display.max_columns', None)

# Caminho para os arquivos que seu script anterior GEROU
path_leitura = '../../../planilhas/limpo/modulo_1/inscricao_coluna_CINE/'

# Coluna que você quer analisar
coluna_para_analisar = 'NO_CINE_AREA_GERAL' 

# --- 2. Verificar o diretório ---
print(f"Iniciando leitura dos arquivos em: {path_leitura}\n")

if not os.path.exists(path_leitura):
    print(f"ERRO: O diretório não existe: {path_leitura}")
else:
    try:
        lista_nomes_arquivos = os.listdir(path_leitura)
        # Ordenar a lista ajuda a ver os resultados em ordem cronológica
        lista_nomes_arquivos.sort() 
    except Exception as e:
        print(f"ERRO ao ler o diretório: {e}")
        lista_nomes_arquivos = []

    if not lista_nomes_arquivos:
        print("Nenhum arquivo encontrado no diretório.")

    # --- 3. Loop de Análise Individual ---
    for arquivo in lista_nomes_arquivos:
        
        if arquivo.endswith('.csv'):
            caminho_completo = os.path.join(path_leitura, arquivo)
            
            # Imprime um cabeçalho para cada arquivo
            print(f"\n{'='*80}")
            print(f"--- Iniciando Análise do Arquivo: {arquivo} ---")
            print(f"{'='*80}")
            
            try:
                # Lê o dataframe individual
                df_temp = pd.read_csv(caminho_completo, low_memory=False)
                
                # Verifica se a coluna de análise realmente existe neste arquivo
                if coluna_para_analisar not in df_temp.columns:
                    print(f"  ERRO: A coluna '{coluna_para_analisar}' não foi encontrada neste arquivo!")
                    print(f"  Colunas disponíveis: {df_temp.columns.to_list()}")
                else:
                    # --- 4. Executar o "Group By + Count" (com value_counts) ---
                    print(f"\n  Contagem de valores para '{coluna_para_analisar}':")
                    
                    # value_counts(dropna=False) faz o groupby+count, INCLUINDO NaNs
                    contagem = df_temp[coluna_para_analisar].value_counts(dropna=False)
                    
                    # Imprime a contagem
                    print(contagem)

                    # --- 5. Resumo explícito dos NaNs para ESTE arquivo ---
                    print("\n  --- Resumo dos NaNs (para este arquivo) ---")
                    
                    total_linhas = len(df_temp)
                    total_nans = df_temp[coluna_para_analisar].isnull().sum()
                    
                    if total_linhas > 0:
                        percentual_nans = (total_nans / total_linhas) * 100
                        print(f"  Total de inscritos (linhas): {total_linhas}")
                        print(f"  Total de NaNs (cursos não encontrados): {total_nans}")
                        print(f"  Percentual de NaNs: {percentual_nans:.2f}%")
                    else:
                        print("  Arquivo está vazio.")
                        
            except Exception as e:
                print(f"  *** ERRO GERAL ao processar o arquivo {arquivo}: {e} ***")

    print(f"\n{'='*80}")
    print("--- Análise individual de todos os arquivos concluída. ---")
    print(f"{'='*80}")
# Out:
# Iniciando leitura dos arquivos em: ../../../planilhas/limpo/modulo_1/inscricao_coluna_CINE/
#
#
# ================================================================================
# --- Iniciando Análise do Arquivo: fies_1_inscricao_2019_limpo_cine.csv ---
# ================================================================================
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Saúde e bem-estar                                             285168
# Negócios, administração e direito                             184212
# Engenharia, produção e construção                              68114
# Ciências sociais, comunicação e informação                     46850
# Educação                                                       26865
# NaN                                                            23906
# Agricultura, silvicultura, pesca e veterinária                 23475
# Computação e Tecnologias da Informação e Comunicação (TIC)     18861
# Serviços                                                       10276
# Artes e humanidades                                             6388
# Ciências naturais, matemática e estatística                     2616
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este arquivo) ---
#   Total de inscritos (linhas): 696731
#   Total de NaNs (cursos não encontrados): 23906
#   Percentual de NaNs: 3.43%
#
# ================================================================================
# --- Iniciando Análise do Arquivo: fies_1_inscricao_2020_limpo_cine.csv ---
# ================================================================================
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Saúde e bem-estar                                             247826
# Negócios, administração e direito                             128630
# Engenharia, produção e construção                              42728
# Ciências sociais, comunicação e informação                     41236
# Agricultura, silvicultura, pesca e veterinária                 20995
# Educação                                                       16422
# Computação e Tecnologias da Informação e Comunicação (TIC)     14998
# NaN                                                            12119
# Serviços                                                        7985
# Artes e humanidades                                             4620
# Ciências naturais, matemática e estatística                     1814
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este arquivo) ---
#   Total de inscritos (linhas): 539373
#   Total de NaNs (cursos não encontrados): 12119
#   Percentual de NaNs: 2.25%
#
# ================================================================================
# --- Iniciando Análise do Arquivo: fies_1_inscricao_2021_limpo_cine.csv ---
# ================================================================================
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Saúde e bem-estar                                             139169
# Negócios, administração e direito                              50598
# Ciências sociais, comunicação e informação                     17902
# Engenharia, produção e construção                              14636
# Agricultura, silvicultura, pesca e veterinária                 10016
# Computação e Tecnologias da Informação e Comunicação (TIC)      5309
# Educação                                                        4951
# NaN                                                             3213
# Serviços                                                        2679
# Artes e humanidades                                             1922
# Ciências naturais, matemática e estatística                      623
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este arquivo) ---
#   Total de inscritos (linhas): 251018
#   Total de NaNs (cursos não encontrados): 3213
#   Percentual de NaNs: 1.28%
#
# ================================================================================
# --- Iniciando Análise do Arquivo: fies_2_inscricao_2019_limpo_cine.csv ---
# ================================================================================
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Saúde e bem-estar                                             121828
# Negócios, administração e direito                              71449
# Engenharia, produção e construção                              24234
# Ciências sociais, comunicação e informação                     18811
# Agricultura, silvicultura, pesca e veterinária                  9433
# Educação                                                        7280
# Computação e Tecnologias da Informação e Comunicação (TIC)      6715
# NaN                                                             4913
# Serviços                                                        3854
# Artes e humanidades                                             2105
# Ciências naturais, matemática e estatística                      694
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este arquivo) ---
#   Total de inscritos (linhas): 271316
#   Total de NaNs (cursos não encontrados): 4913
#   Percentual de NaNs: 1.81%
#
# ================================================================================
# --- Iniciando Análise do Arquivo: fies_2_inscricao_2020_limpo_cine.csv ---
# ================================================================================
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Saúde e bem-estar                                             109912
# Negócios, administração e direito                              46003
# Ciências sociais, comunicação e informação                     14981
# Engenharia, produção e construção                              13475
# Agricultura, silvicultura, pesca e veterinária                  8139
# Educação                                                        4267
# Computação e Tecnologias da Informação e Comunicação (TIC)      4120
# NaN                                                             4079
# Serviços                                                        2539
# Artes e humanidades                                             1519
# Ciências naturais, matemática e estatística                      468
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este arquivo) ---
#   Total de inscritos (linhas): 209502
#   Total de NaNs (cursos não encontrados): 4079
#   Percentual de NaNs: 1.95%
#
# ================================================================================
# --- Iniciando Análise do Arquivo: fies_2_inscricao_2021_limpo_cine.csv ---
# ================================================================================
#
#   Contagem de valores para 'NO_CINE_AREA_GERAL':
# NO_CINE_AREA_GERAL
# Saúde e bem-estar                                             132640
# Negócios, administração e direito                              44009
# Ciências sociais, comunicação e informação                     15990
# Engenharia, produção e construção                              12559
# Agricultura, silvicultura, pesca e veterinária                  9778
# Computação e Tecnologias da Informação e Comunicação (TIC)      4703
# Educação                                                        3485
# NaN                                                             2178
# Serviços                                                        1943
# Artes e humanidades                                             1517
# Ciências naturais, matemática e estatística                      492
# Name: count, dtype: int64
#
#   --- Resumo dos NaNs (para este arquivo) ---
#   Total de inscritos (linhas): 229294
#   Total de NaNs (cursos não encontrados): 2178
#   Percentual de NaNs: 0.95%
#
# ================================================================================
# --- Análise individual de todos os arquivos concluída. ---
# ================================================================================

# %%
import pandas as pd

# Dicionário para guardar o conjunto (set) de colunas de cada ano
colunas_por_ano = {}

print("Iniciando verificação dos cabeçalhos...\n")

# --- ETAPA 1: Ler os cabeçalhos de cada arquivo ---
for ano in range(2016,2025): # 2025 nao eh incluso entao vai ate 2024
    caminho_externo = f'../../../planilhas/externo/MICRODADOS_CADASTRO_CURSOS_{ano}.csv'
    
    print(f"--- Processando {ano} ---")
    try:
        # Usamos nrows=0 para ler APENAS o cabeçalho.
        # É extremamente rápido e economiza memória.
        df_header = pd.read_csv(
            caminho_externo,
            encoding='latin-1',
            sep=';',
            decimal=',',
            nrows=5 
        )
        
        # Armazena as colunas como um 'set' para facilitar a comparação
        colunas_por_ano[ano] = set(df_header.columns)
        print(f"Arquivo {ano} lido com sucesso. Total: {len(df_header.columns)} colunas.")
        
    except FileNotFoundError:
        print(f"!!! ERRO: Arquivo não encontrado em: {caminho_externo}")
        colunas_por_ano[ano] = None # Marca que este ano falhou
    except Exception as e:
        print(f"!!! ERRO ao ler o arquivo {ano}: {e}")
        colunas_por_ano[ano] = None

print("\n--- Verificação Concluída ---")


# --- ETAPA 2: Comparar os conjuntos de colunas ---
anos_validos = [ano for ano, colunas in colunas_por_ano.items() if colunas is not None]

if len(anos_validos) >= 2:
    print("\n--- Comparando Conjuntos de Colunas ---")
    
    # Pega o primeiro ano lido com sucesso como nossa referência
    ano_referencia = anos_validos[0]
    colunas_referencia = colunas_por_ano[ano_referencia]
    
    print(f"Usando {ano_referencia} como referência ({len(colunas_referencia)} colunas).")
    
    # Compara os outros anos com a referência
    for i in range(1, len(anos_validos)):
        ano_comparar = anos_validos[i]
        colunas_comparar = colunas_por_ano[ano_comparar]
        
        print(f"\nComparando {ano_referencia} vs {ano_comparar}:")
        
        # Colunas que estão na referência mas não no outro
        diferenca_1 = colunas_referencia - colunas_comparar
        if diferenca_1:
            print(f"  > Colunas em {ano_referencia} que NÃO estão em {ano_comparar}: {diferenca_1}")
        
        # Colunas que estão no outro mas não na referência
        diferenca_2 = colunas_comparar - colunas_referencia
        if diferenca_2:
            print(f"  > Colunas em {ano_comparar} que NÃO estão em {ano_referencia}: {diferenca_2}")
        
        if not diferenca_1 and not diferenca_2:
            print("  > Os conjuntos de colunas são IDÊNTICOS.")
else:
    print("\nNão foi possível comparar os arquivos (menos de 2 arquivos lidos com sucesso).")


# --- ETAPA 3: Listagem completa (para você me enviar) ---
print("\n\n--- Listagem Bruta das Colunas (para você me enviar) ---")
for ano, colunas in colunas_por_ano.items():
    if colunas is not None:
        print(f"\n====================\nCOLUNAS {ano}\n====================")
        # Imprime uma por linha, em ordem alfabética, para facilitar a leitura
        for col in sorted(list(colunas)):
            print(col)
    else:
        print(f"\n====================\nCOLUNAS {ano}\n====================\n(Falha na leitura)")
# Out:
# Iniciando verificação dos cabeçalhos...
#
# --- Processando 2016 ---
# Arquivo 2016 lido com sucesso. Total: 200 colunas.
# --- Processando 2017 ---
# Arquivo 2017 lido com sucesso. Total: 200 colunas.
# --- Processando 2018 ---
# Arquivo 2018 lido com sucesso. Total: 200 colunas.
# --- Processando 2019 ---
# Arquivo 2019 lido com sucesso. Total: 200 colunas.
# --- Processando 2020 ---
# Arquivo 2020 lido com sucesso. Total: 200 colunas.
# --- Processando 2021 ---
# Arquivo 2021 lido com sucesso. Total: 200 colunas.
# --- Processando 2022 ---
# Arquivo 2022 lido com sucesso. Total: 200 colunas.
# --- Processando 2023 ---
# Arquivo 2023 lido com sucesso. Total: 202 colunas.
# --- Processando 2024 ---
# Arquivo 2024 lido com sucesso. Total: 223 colunas.
#
# --- Verificação Concluída ---
#
# --- Comparando Conjuntos de Colunas ---
# Usando 2016 como referência (200 colunas).
#
# Comparando 2016 vs 2017:
#   > Os conjuntos de colunas são IDÊNTICOS.
#
# Comparando 2016 vs 2018:
#   > Os conjuntos de colunas são IDÊNTICOS.
#
# Comparando 2016 vs 2019:
#   > Os conjuntos de colunas são IDÊNTICOS.
#
# Comparando 2016 vs 2020:
#   > Colunas em 2016 que NÃO estão em 2020: {'CO_CINE_ROTULO'}
#   > Colunas em 2020 que NÃO estão em 2016: {'CO_CINE_ROTULO2'}
#
# Comparando 2016 vs 2021:
#   > Os conjuntos de colunas são IDÊNTICOS.
#
# Comparando 2016 vs 2022:
#   > Os conjuntos de colunas são IDÊNTICOS.
#
# Comparando 2016 vs 2023:
#   > Colunas em 2023 que NÃO estão em 2016: {'IN_CONFESSIONAL', 'IN_COMUNITARIA'}
#
# Comparando 2016 vs 2024:
#   > Colunas em 2016 que NÃO estão em 2024: {'QT_CONC_RVETNICO', 'QT_MAT_RVETNICO', 'QT_ING_RVETNICO'}
#   > Colunas em 2024 que NÃO estão em 2016: {'QT_CONC_RVMEDAL', 'QT_ING_RVIDOSO', 'QT_MAT_RVINTERN', 'IN_CONFESSIONAL', 'QT_CONC_RVINTERN', 'QT_MAT_RVQUILO', 'QT_MAT_RVIDOSO', 'IN_COMUNITARIA', 'QT_MAT_RVREFU', 'QT_ING_RVMEDAL', 'QT_MAT_RVPOVT', 'QT_CONC_RVREFU', 'QT_MAT_RVMEDAL', 'QT_ING_RVPPI', 'QT_ING_RVREFU', 'QT_ING_RVQUILO', 'QT_MAT_RVPPI', 'QT_ING_RVINTERN', 'QT_CONC_RVQUILO', 'QT_CONC_RVTRANS', 'QT_MAT_RVTRANS', 'QT_CONC_RVIDOSO', 'QT_ING_RVTRANS', 'QT_CONC_RVPPI', 'QT_ING_RVPOVT', 'QT_CONC_RVPOVT'}
#
#
# --- Listagem Bruta das Colunas (para você me enviar) ---
#
# ====================
# COLUNAS 2016
# ====================
# CO_CINE_AREA_DETALHADA
# CO_CINE_AREA_ESPECIFICA
# CO_CINE_AREA_GERAL
# CO_CINE_ROTULO
# CO_CURSO
# CO_IES
# CO_MUNICIPIO
# CO_REGIAO
# CO_UF
# IN_CAPITAL
# IN_GRATUITO
# NO_CINE_AREA_DETALHADA
# NO_CINE_AREA_ESPECIFICA
# NO_CINE_AREA_GERAL
# NO_CINE_ROTULO
# NO_CURSO
# NO_MUNICIPIO
# NO_REGIAO
# NO_UF
# NU_ANO_CENSO
# QT_ALUNO_DEFICIENTE
# QT_APOIO_SOCIAL
# QT_ATIV_EXTRACURRICULAR
# QT_CONC
# QT_CONC_0_17
# QT_CONC_18_24
# QT_CONC_25_29
# QT_CONC_30_34
# QT_CONC_35_39
# QT_CONC_40_49
# QT_CONC_50_59
# QT_CONC_60_MAIS
# QT_CONC_AMARELA
# QT_CONC_APOIO_SOCIAL
# QT_CONC_ATIV_EXTRACURRICULAR
# QT_CONC_BRANCA
# QT_CONC_CORND
# QT_CONC_DEFICIENTE
# QT_CONC_DIURNO
# QT_CONC_FEM
# QT_CONC_FIES
# QT_CONC_FINANC
# QT_CONC_FINANC_NREEMB
# QT_CONC_FINANC_NREEMB_OUTROS
# QT_CONC_FINANC_REEMB
# QT_CONC_FINANC_REEMB_OUTROS
# QT_CONC_INDIGENA
# QT_CONC_MASC
# QT_CONC_MOB_ACADEMICA
# QT_CONC_NACBRAS
# QT_CONC_NACESTRANG
# QT_CONC_NOTURNO
# QT_CONC_NRPFIES
# QT_CONC_PARDA
# QT_CONC_PARFOR
# QT_CONC_PRETA
# QT_CONC_PROCESCPRIVADA
# QT_CONC_PROCESCPUBLICA
# QT_CONC_PROCNAOINFORMADA
# QT_CONC_PROUNII
# QT_CONC_PROUNIP
# QT_CONC_RESERVA_VAGA
# QT_CONC_RPFIES
# QT_CONC_RVETNICO
# QT_CONC_RVOUTROS
# QT_CONC_RVPDEF
# QT_CONC_RVREDEPUBLICA
# QT_CONC_RVSOCIAL_RF
# QT_CURSO
# QT_ING
# QT_ING_0_17
# QT_ING_18_24
# QT_ING_25_29
# QT_ING_30_34
# QT_ING_35_39
# QT_ING_40_49
# QT_ING_50_59
# QT_ING_60_MAIS
# QT_ING_AMARELA
# QT_ING_APOIO_SOCIAL
# QT_ING_ATIV_EXTRACURRICULAR
# QT_ING_AVALIACAO_SERIADA
# QT_ING_BRANCA
# QT_ING_CORND
# QT_ING_DEFICIENTE
# QT_ING_DIURNO
# QT_ING_EGR
# QT_ING_ENEM
# QT_ING_FEM
# QT_ING_FIES
# QT_ING_FINANC
# QT_ING_FINANC_NREEMB
# QT_ING_FINANC_NREEMB_OUTROS
# QT_ING_FINANC_REEMB
# QT_ING_FINANC_REEMB_OUTROS
# QT_ING_INDIGENA
# QT_ING_MASC
# QT_ING_MOB_ACADEMICA
# QT_ING_NACBRAS
# QT_ING_NACESTRANG
# QT_ING_NOTURNO
# QT_ING_NRPFIES
# QT_ING_OUTRA_FORMA
# QT_ING_OUTRO_TIPO_SELECAO
# QT_ING_PARDA
# QT_ING_PARFOR
# QT_ING_PRETA
# QT_ING_PROCESCPRIVADA
# QT_ING_PROCESCPUBLICA
# QT_ING_PROCNAOINFORMADA
# QT_ING_PROC_SELETIVO
# QT_ING_PROUNII
# QT_ING_PROUNIP
# QT_ING_RESERVA_VAGA
# QT_ING_RPFIES
# QT_ING_RVETNICO
# QT_ING_RVOUTROS
# QT_ING_RVPDEF
# QT_ING_RVREDEPUBLICA
# QT_ING_RVSOCIAL_RF
# QT_ING_SELECAO_SIMPLIFICA
# QT_ING_VESTIBULAR
# QT_ING_VG_NOVA
# QT_ING_VG_PROG_ESPECIAL
# QT_ING_VG_REMANESC
# QT_INSCRITO_TOTAL
# QT_INSCRITO_TOTAL_DIURNO
# QT_INSCRITO_TOTAL_EAD
# QT_INSCRITO_TOTAL_NOTURNO
# QT_INSC_PROC_SELETIVO
# QT_INSC_VG_NOVA
# QT_INSC_VG_PROG_ESPECIAL
# QT_INSC_VG_REMANESC
# QT_MAT
# QT_MAT_0_17
# QT_MAT_18_24
# QT_MAT_25_29
# QT_MAT_30_34
# QT_MAT_35_39
# QT_MAT_40_49
# QT_MAT_50_59
# QT_MAT_60_MAIS
# QT_MAT_AMARELA
# QT_MAT_APOIO_SOCIAL
# QT_MAT_ATIV_EXTRACURRICULAR
# QT_MAT_BRANCA
# QT_MAT_CORND
# QT_MAT_DEFICIENTE
# QT_MAT_DIURNO
# QT_MAT_FEM
# QT_MAT_FIES
# QT_MAT_FINANC
# QT_MAT_FINANC_NREEMB
# QT_MAT_FINANC_NREEMB_OUTROS
# QT_MAT_FINANC_REEMB
# QT_MAT_FINANC_REEMB_OUTROS
# QT_MAT_INDIGENA
# QT_MAT_MASC
# QT_MAT_MOB_ACADEMICA
# QT_MAT_NACBRAS
# QT_MAT_NACESTRANG
# QT_MAT_NOTURNO
# QT_MAT_NRPFIES
# QT_MAT_PARDA
# QT_MAT_PARFOR
# QT_MAT_PRETA
# QT_MAT_PROCESCPRIVADA
# QT_MAT_PROCESCPUBLICA
# QT_MAT_PROCNAOINFORMADA
# QT_MAT_PROUNII
# QT_MAT_PROUNIP
# QT_MAT_RESERVA_VAGA
# QT_MAT_RPFIES
# QT_MAT_RVETNICO
# QT_MAT_RVOUTROS
# QT_MAT_RVPDEF
# QT_MAT_RVREDEPUBLICA
# QT_MAT_RVSOCIAL_RF
# QT_MOB_ACADEMICA
# QT_PARFOR
# QT_SIT_DESVINCULADO
# QT_SIT_FALECIDO
# QT_SIT_TRANCADA
# QT_SIT_TRANSFERIDO
# QT_VG_NOVA
# QT_VG_PROC_SELETIVO
# QT_VG_PROG_ESPECIAL
# QT_VG_REMANESC
# QT_VG_TOTAL
# QT_VG_TOTAL_DIURNO
# QT_VG_TOTAL_EAD
# QT_VG_TOTAL_NOTURNO
# SG_UF
# TP_CATEGORIA_ADMINISTRATIVA
# TP_DIMENSAO
# TP_GRAU_ACADEMICO
# TP_MODALIDADE_ENSINO
# TP_NIVEL_ACADEMICO
# TP_ORGANIZACAO_ACADEMICA
# TP_REDE
#
# ====================
# COLUNAS 2017
# ====================
# CO_CINE_AREA_DETALHADA
# CO_CINE_AREA_ESPECIFICA
# CO_CINE_AREA_GERAL
# CO_CINE_ROTULO
# CO_CURSO
# CO_IES
# CO_MUNICIPIO
# CO_REGIAO
# CO_UF
# IN_CAPITAL
# IN_GRATUITO
# NO_CINE_AREA_DETALHADA
# NO_CINE_AREA_ESPECIFICA
# NO_CINE_AREA_GERAL
# NO_CINE_ROTULO
# NO_CURSO
# NO_MUNICIPIO
# NO_REGIAO
# NO_UF
# NU_ANO_CENSO
# QT_ALUNO_DEFICIENTE
# QT_APOIO_SOCIAL
# QT_ATIV_EXTRACURRICULAR
# QT_CONC
# QT_CONC_0_17
# QT_CONC_18_24
# QT_CONC_25_29
# QT_CONC_30_34
# QT_CONC_35_39
# QT_CONC_40_49
# QT_CONC_50_59
# QT_CONC_60_MAIS
# QT_CONC_AMARELA
# QT_CONC_APOIO_SOCIAL
# QT_CONC_ATIV_EXTRACURRICULAR
# QT_CONC_BRANCA
# QT_CONC_CORND
# QT_CONC_DEFICIENTE
# QT_CONC_DIURNO
# QT_CONC_FEM
# QT_CONC_FIES
# QT_CONC_FINANC
# QT_CONC_FINANC_NREEMB
# QT_CONC_FINANC_NREEMB_OUTROS
# QT_CONC_FINANC_REEMB
# QT_CONC_FINANC_REEMB_OUTROS
# QT_CONC_INDIGENA
# QT_CONC_MASC
# QT_CONC_MOB_ACADEMICA
# QT_CONC_NACBRAS
# QT_CONC_NACESTRANG
# QT_CONC_NOTURNO
# QT_CONC_NRPFIES
# QT_CONC_PARDA
# QT_CONC_PARFOR
# QT_CONC_PRETA
# QT_CONC_PROCESCPRIVADA
# QT_CONC_PROCESCPUBLICA
# QT_CONC_PROCNAOINFORMADA
# QT_CONC_PROUNII
# QT_CONC_PROUNIP
# QT_CONC_RESERVA_VAGA
# QT_CONC_RPFIES
# QT_CONC_RVETNICO
# QT_CONC_RVOUTROS
# QT_CONC_RVPDEF
# QT_CONC_RVREDEPUBLICA
# QT_CONC_RVSOCIAL_RF
# QT_CURSO
# QT_ING
# QT_ING_0_17
# QT_ING_18_24
# QT_ING_25_29
# QT_ING_30_34
# QT_ING_35_39
# QT_ING_40_49
# QT_ING_50_59
# QT_ING_60_MAIS
# QT_ING_AMARELA
# QT_ING_APOIO_SOCIAL
# QT_ING_ATIV_EXTRACURRICULAR
# QT_ING_AVALIACAO_SERIADA
# QT_ING_BRANCA
# QT_ING_CORND
# QT_ING_DEFICIENTE
# QT_ING_DIURNO
# QT_ING_EGR
# QT_ING_ENEM
# QT_ING_FEM
# QT_ING_FIES
# QT_ING_FINANC
# QT_ING_FINANC_NREEMB
# QT_ING_FINANC_NREEMB_OUTROS
# QT_ING_FINANC_REEMB
# QT_ING_FINANC_REEMB_OUTROS
# QT_ING_INDIGENA
# QT_ING_MASC
# QT_ING_MOB_ACADEMICA
# QT_ING_NACBRAS
# QT_ING_NACESTRANG
# QT_ING_NOTURNO
# QT_ING_NRPFIES
# QT_ING_OUTRA_FORMA
# QT_ING_OUTRO_TIPO_SELECAO
# QT_ING_PARDA
# QT_ING_PARFOR
# QT_ING_PRETA
# QT_ING_PROCESCPRIVADA
# QT_ING_PROCESCPUBLICA
# QT_ING_PROCNAOINFORMADA
# QT_ING_PROC_SELETIVO
# QT_ING_PROUNII
# QT_ING_PROUNIP
# QT_ING_RESERVA_VAGA
# QT_ING_RPFIES
# QT_ING_RVETNICO
# QT_ING_RVOUTROS
# QT_ING_RVPDEF
# QT_ING_RVREDEPUBLICA
# QT_ING_RVSOCIAL_RF
# QT_ING_SELECAO_SIMPLIFICA
# QT_ING_VESTIBULAR
# QT_ING_VG_NOVA
# QT_ING_VG_PROG_ESPECIAL
# QT_ING_VG_REMANESC
# QT_INSCRITO_TOTAL
# QT_INSCRITO_TOTAL_DIURNO
# QT_INSCRITO_TOTAL_EAD
# QT_INSCRITO_TOTAL_NOTURNO
# QT_INSC_PROC_SELETIVO
# QT_INSC_VG_NOVA
# QT_INSC_VG_PROG_ESPECIAL
# QT_INSC_VG_REMANESC
# QT_MAT
# QT_MAT_0_17
# QT_MAT_18_24
# QT_MAT_25_29
# QT_MAT_30_34
# QT_MAT_35_39
# QT_MAT_40_49
# QT_MAT_50_59
# QT_MAT_60_MAIS
# QT_MAT_AMARELA
# QT_MAT_APOIO_SOCIAL
# QT_MAT_ATIV_EXTRACURRICULAR
# QT_MAT_BRANCA
# QT_MAT_CORND
# QT_MAT_DEFICIENTE
# QT_MAT_DIURNO
# QT_MAT_FEM
# QT_MAT_FIES
# QT_MAT_FINANC
# QT_MAT_FINANC_NREEMB
# QT_MAT_FINANC_NREEMB_OUTROS
# QT_MAT_FINANC_REEMB
# QT_MAT_FINANC_REEMB_OUTROS
# QT_MAT_INDIGENA
# QT_MAT_MASC
# QT_MAT_MOB_ACADEMICA
# QT_MAT_NACBRAS
# QT_MAT_NACESTRANG
# QT_MAT_NOTURNO
# QT_MAT_NRPFIES
# QT_MAT_PARDA
# QT_MAT_PARFOR
# QT_MAT_PRETA
# QT_MAT_PROCESCPRIVADA
# QT_MAT_PROCESCPUBLICA
# QT_MAT_PROCNAOINFORMADA
# QT_MAT_PROUNII
# QT_MAT_PROUNIP
# QT_MAT_RESERVA_VAGA
# QT_MAT_RPFIES
# QT_MAT_RVETNICO
# QT_MAT_RVOUTROS
# QT_MAT_RVPDEF
# QT_MAT_RVREDEPUBLICA
# QT_MAT_RVSOCIAL_RF
# QT_MOB_ACADEMICA
# QT_PARFOR
# QT_SIT_DESVINCULADO
# QT_SIT_FALECIDO
# QT_SIT_TRANCADA
# QT_SIT_TRANSFERIDO
# QT_VG_NOVA
# QT_VG_PROC_SELETIVO
# QT_VG_PROG_ESPECIAL
# QT_VG_REMANESC
# QT_VG_TOTAL
# QT_VG_TOTAL_DIURNO
# QT_VG_TOTAL_EAD
# QT_VG_TOTAL_NOTURNO
# SG_UF
# TP_CATEGORIA_ADMINISTRATIVA
# TP_DIMENSAO
# TP_GRAU_ACADEMICO
# TP_MODALIDADE_ENSINO
# TP_NIVEL_ACADEMICO
# TP_ORGANIZACAO_ACADEMICA
# TP_REDE
#
# ====================
# COLUNAS 2018
# ====================
# CO_CINE_AREA_DETALHADA
# CO_CINE_AREA_ESPECIFICA
# CO_CINE_AREA_GERAL
# CO_CINE_ROTULO
# CO_CURSO
# CO_IES
# CO_MUNICIPIO
# CO_REGIAO
# CO_UF
# IN_CAPITAL
# IN_GRATUITO
# NO_CINE_AREA_DETALHADA
# NO_CINE_AREA_ESPECIFICA
# NO_CINE_AREA_GERAL
# NO_CINE_ROTULO
# NO_CURSO
# NO_MUNICIPIO
# NO_REGIAO
# NO_UF
# NU_ANO_CENSO
# QT_ALUNO_DEFICIENTE
# QT_APOIO_SOCIAL
# QT_ATIV_EXTRACURRICULAR
# QT_CONC
# QT_CONC_0_17
# QT_CONC_18_24
# QT_CONC_25_29
# QT_CONC_30_34
# QT_CONC_35_39
# QT_CONC_40_49
# QT_CONC_50_59
# QT_CONC_60_MAIS
# QT_CONC_AMARELA
# QT_CONC_APOIO_SOCIAL
# QT_CONC_ATIV_EXTRACURRICULAR
# QT_CONC_BRANCA
# QT_CONC_CORND
# QT_CONC_DEFICIENTE
# QT_CONC_DIURNO
# QT_CONC_FEM
# QT_CONC_FIES
# QT_CONC_FINANC
# QT_CONC_FINANC_NREEMB
# QT_CONC_FINANC_NREEMB_OUTROS
# QT_CONC_FINANC_REEMB
# QT_CONC_FINANC_REEMB_OUTROS
# QT_CONC_INDIGENA
# QT_CONC_MASC
# QT_CONC_MOB_ACADEMICA
# QT_CONC_NACBRAS
# QT_CONC_NACESTRANG
# QT_CONC_NOTURNO
# QT_CONC_NRPFIES
# QT_CONC_PARDA
# QT_CONC_PARFOR
# QT_CONC_PRETA
# QT_CONC_PROCESCPRIVADA
# QT_CONC_PROCESCPUBLICA
# QT_CONC_PROCNAOINFORMADA
# QT_CONC_PROUNII
# QT_CONC_PROUNIP
# QT_CONC_RESERVA_VAGA
# QT_CONC_RPFIES
# QT_CONC_RVETNICO
# QT_CONC_RVOUTROS
# QT_CONC_RVPDEF
# QT_CONC_RVREDEPUBLICA
# QT_CONC_RVSOCIAL_RF
# QT_CURSO
# QT_ING
# QT_ING_0_17
# QT_ING_18_24
# QT_ING_25_29
# QT_ING_30_34
# QT_ING_35_39
# QT_ING_40_49
# QT_ING_50_59
# QT_ING_60_MAIS
# QT_ING_AMARELA
# QT_ING_APOIO_SOCIAL
# QT_ING_ATIV_EXTRACURRICULAR
# QT_ING_AVALIACAO_SERIADA
# QT_ING_BRANCA
# QT_ING_CORND
# QT_ING_DEFICIENTE
# QT_ING_DIURNO
# QT_ING_EGR
# QT_ING_ENEM
# QT_ING_FEM
# QT_ING_FIES
# QT_ING_FINANC
# QT_ING_FINANC_NREEMB
# QT_ING_FINANC_NREEMB_OUTROS
# QT_ING_FINANC_REEMB
# QT_ING_FINANC_REEMB_OUTROS
# QT_ING_INDIGENA
# QT_ING_MASC
# QT_ING_MOB_ACADEMICA
# QT_ING_NACBRAS
# QT_ING_NACESTRANG
# QT_ING_NOTURNO
# QT_ING_NRPFIES
# QT_ING_OUTRA_FORMA
# QT_ING_OUTRO_TIPO_SELECAO
# QT_ING_PARDA
# QT_ING_PARFOR
# QT_ING_PRETA
# QT_ING_PROCESCPRIVADA
# QT_ING_PROCESCPUBLICA
# QT_ING_PROCNAOINFORMADA
# QT_ING_PROC_SELETIVO
# QT_ING_PROUNII
# QT_ING_PROUNIP
# QT_ING_RESERVA_VAGA
# QT_ING_RPFIES
# QT_ING_RVETNICO
# QT_ING_RVOUTROS
# QT_ING_RVPDEF
# QT_ING_RVREDEPUBLICA
# QT_ING_RVSOCIAL_RF
# QT_ING_SELECAO_SIMPLIFICA
# QT_ING_VESTIBULAR
# QT_ING_VG_NOVA
# QT_ING_VG_PROG_ESPECIAL
# QT_ING_VG_REMANESC
# QT_INSCRITO_TOTAL
# QT_INSCRITO_TOTAL_DIURNO
# QT_INSCRITO_TOTAL_EAD
# QT_INSCRITO_TOTAL_NOTURNO
# QT_INSC_PROC_SELETIVO
# QT_INSC_VG_NOVA
# QT_INSC_VG_PROG_ESPECIAL
# QT_INSC_VG_REMANESC
# QT_MAT
# QT_MAT_0_17
# QT_MAT_18_24
# QT_MAT_25_29
# QT_MAT_30_34
# QT_MAT_35_39
# QT_MAT_40_49
# QT_MAT_50_59
# QT_MAT_60_MAIS
# QT_MAT_AMARELA
# QT_MAT_APOIO_SOCIAL
# QT_MAT_ATIV_EXTRACURRICULAR
# QT_MAT_BRANCA
# QT_MAT_CORND
# QT_MAT_DEFICIENTE
# QT_MAT_DIURNO
# QT_MAT_FEM
# QT_MAT_FIES
# QT_MAT_FINANC
# QT_MAT_FINANC_NREEMB
# QT_MAT_FINANC_NREEMB_OUTROS
# QT_MAT_FINANC_REEMB
# QT_MAT_FINANC_REEMB_OUTROS
# QT_MAT_INDIGENA
# QT_MAT_MASC
# QT_MAT_MOB_ACADEMICA
# QT_MAT_NACBRAS
# QT_MAT_NACESTRANG
# QT_MAT_NOTURNO
# QT_MAT_NRPFIES
# QT_MAT_PARDA
# QT_MAT_PARFOR
# QT_MAT_PRETA
# QT_MAT_PROCESCPRIVADA
# QT_MAT_PROCESCPUBLICA
# QT_MAT_PROCNAOINFORMADA
# QT_MAT_PROUNII
# QT_MAT_PROUNIP
# QT_MAT_RESERVA_VAGA
# QT_MAT_RPFIES
# QT_MAT_RVETNICO
# QT_MAT_RVOUTROS
# QT_MAT_RVPDEF
# QT_MAT_RVREDEPUBLICA
# QT_MAT_RVSOCIAL_RF
# QT_MOB_ACADEMICA
# QT_PARFOR
# QT_SIT_DESVINCULADO
# QT_SIT_FALECIDO
# QT_SIT_TRANCADA
# QT_SIT_TRANSFERIDO
# QT_VG_NOVA
# QT_VG_PROC_SELETIVO
# QT_VG_PROG_ESPECIAL
# QT_VG_REMANESC
# QT_VG_TOTAL
# QT_VG_TOTAL_DIURNO
# QT_VG_TOTAL_EAD
# QT_VG_TOTAL_NOTURNO
# SG_UF
# TP_CATEGORIA_ADMINISTRATIVA
# TP_DIMENSAO
# TP_GRAU_ACADEMICO
# TP_MODALIDADE_ENSINO
# TP_NIVEL_ACADEMICO
# TP_ORGANIZACAO_ACADEMICA
# TP_REDE
#
# ====================
# COLUNAS 2019
# ====================
# CO_CINE_AREA_DETALHADA
# CO_CINE_AREA_ESPECIFICA
# CO_CINE_AREA_GERAL
# CO_CINE_ROTULO
# CO_CURSO
# CO_IES
# CO_MUNICIPIO
# CO_REGIAO
# CO_UF
# IN_CAPITAL
# IN_GRATUITO
# NO_CINE_AREA_DETALHADA
# NO_CINE_AREA_ESPECIFICA
# NO_CINE_AREA_GERAL
# NO_CINE_ROTULO
# NO_CURSO
# NO_MUNICIPIO
# NO_REGIAO
# NO_UF
# NU_ANO_CENSO
# QT_ALUNO_DEFICIENTE
# QT_APOIO_SOCIAL
# QT_ATIV_EXTRACURRICULAR
# QT_CONC
# QT_CONC_0_17
# QT_CONC_18_24
# QT_CONC_25_29
# QT_CONC_30_34
# QT_CONC_35_39
# QT_CONC_40_49
# QT_CONC_50_59
# QT_CONC_60_MAIS
# QT_CONC_AMARELA
# QT_CONC_APOIO_SOCIAL
# QT_CONC_ATIV_EXTRACURRICULAR
# QT_CONC_BRANCA
# QT_CONC_CORND
# QT_CONC_DEFICIENTE
# QT_CONC_DIURNO
# QT_CONC_FEM
# QT_CONC_FIES
# QT_CONC_FINANC
# QT_CONC_FINANC_NREEMB
# QT_CONC_FINANC_NREEMB_OUTROS
# QT_CONC_FINANC_REEMB
# QT_CONC_FINANC_REEMB_OUTROS
# QT_CONC_INDIGENA
# QT_CONC_MASC
# QT_CONC_MOB_ACADEMICA
# QT_CONC_NACBRAS
# QT_CONC_NACESTRANG
# QT_CONC_NOTURNO
# QT_CONC_NRPFIES
# QT_CONC_PARDA
# QT_CONC_PARFOR
# QT_CONC_PRETA
# QT_CONC_PROCESCPRIVADA
# QT_CONC_PROCESCPUBLICA
# QT_CONC_PROCNAOINFORMADA
# QT_CONC_PROUNII
# QT_CONC_PROUNIP
# QT_CONC_RESERVA_VAGA
# QT_CONC_RPFIES
# QT_CONC_RVETNICO
# QT_CONC_RVOUTROS
# QT_CONC_RVPDEF
# QT_CONC_RVREDEPUBLICA
# QT_CONC_RVSOCIAL_RF
# QT_CURSO
# QT_ING
# QT_ING_0_17
# QT_ING_18_24
# QT_ING_25_29
# QT_ING_30_34
# QT_ING_35_39
# QT_ING_40_49
# QT_ING_50_59
# QT_ING_60_MAIS
# QT_ING_AMARELA
# QT_ING_APOIO_SOCIAL
# QT_ING_ATIV_EXTRACURRICULAR
# QT_ING_AVALIACAO_SERIADA
# QT_ING_BRANCA
# QT_ING_CORND
# QT_ING_DEFICIENTE
# QT_ING_DIURNO
# QT_ING_EGR
# QT_ING_ENEM
# QT_ING_FEM
# QT_ING_FIES
# QT_ING_FINANC
# QT_ING_FINANC_NREEMB
# QT_ING_FINANC_NREEMB_OUTROS
# QT_ING_FINANC_REEMB
# QT_ING_FINANC_REEMB_OUTROS
# QT_ING_INDIGENA
# QT_ING_MASC
# QT_ING_MOB_ACADEMICA
# QT_ING_NACBRAS
# QT_ING_NACESTRANG
# QT_ING_NOTURNO
# QT_ING_NRPFIES
# QT_ING_OUTRA_FORMA
# QT_ING_OUTRO_TIPO_SELECAO
# QT_ING_PARDA
# QT_ING_PARFOR
# QT_ING_PRETA
# QT_ING_PROCESCPRIVADA
# QT_ING_PROCESCPUBLICA
# QT_ING_PROCNAOINFORMADA
# QT_ING_PROC_SELETIVO
# QT_ING_PROUNII
# QT_ING_PROUNIP
# QT_ING_RESERVA_VAGA
# QT_ING_RPFIES
# QT_ING_RVETNICO
# QT_ING_RVOUTROS
# QT_ING_RVPDEF
# QT_ING_RVREDEPUBLICA
# QT_ING_RVSOCIAL_RF
# QT_ING_SELECAO_SIMPLIFICA
# QT_ING_VESTIBULAR
# QT_ING_VG_NOVA
# QT_ING_VG_PROG_ESPECIAL
# QT_ING_VG_REMANESC
# QT_INSCRITO_TOTAL
# QT_INSCRITO_TOTAL_DIURNO
# QT_INSCRITO_TOTAL_EAD
# QT_INSCRITO_TOTAL_NOTURNO
# QT_INSC_PROC_SELETIVO
# QT_INSC_VG_NOVA
# QT_INSC_VG_PROG_ESPECIAL
# QT_INSC_VG_REMANESC
# QT_MAT
# QT_MAT_0_17
# QT_MAT_18_24
# QT_MAT_25_29
# QT_MAT_30_34
# QT_MAT_35_39
# QT_MAT_40_49
# QT_MAT_50_59
# QT_MAT_60_MAIS
# QT_MAT_AMARELA
# QT_MAT_APOIO_SOCIAL
# QT_MAT_ATIV_EXTRACURRICULAR
# QT_MAT_BRANCA
# QT_MAT_CORND
# QT_MAT_DEFICIENTE
# QT_MAT_DIURNO
# QT_MAT_FEM
# QT_MAT_FIES
# QT_MAT_FINANC
# QT_MAT_FINANC_NREEMB
# QT_MAT_FINANC_NREEMB_OUTROS
# QT_MAT_FINANC_REEMB
# QT_MAT_FINANC_REEMB_OUTROS
# QT_MAT_INDIGENA
# QT_MAT_MASC
# QT_MAT_MOB_ACADEMICA
# QT_MAT_NACBRAS
# QT_MAT_NACESTRANG
# QT_MAT_NOTURNO
# QT_MAT_NRPFIES
# QT_MAT_PARDA
# QT_MAT_PARFOR
# QT_MAT_PRETA
# QT_MAT_PROCESCPRIVADA
# QT_MAT_PROCESCPUBLICA
# QT_MAT_PROCNAOINFORMADA
# QT_MAT_PROUNII
# QT_MAT_PROUNIP
# QT_MAT_RESERVA_VAGA
# QT_MAT_RPFIES
# QT_MAT_RVETNICO
# QT_MAT_RVOUTROS
# QT_MAT_RVPDEF
# QT_MAT_RVREDEPUBLICA
# QT_MAT_RVSOCIAL_RF
# QT_MOB_ACADEMICA
# QT_PARFOR
# QT_SIT_DESVINCULADO
# QT_SIT_FALECIDO
# QT_SIT_TRANCADA
# QT_SIT_TRANSFERIDO
# QT_VG_NOVA
# QT_VG_PROC_SELETIVO
# QT_VG_PROG_ESPECIAL
# QT_VG_REMANESC
# QT_VG_TOTAL
# QT_VG_TOTAL_DIURNO
# QT_VG_TOTAL_EAD
# QT_VG_TOTAL_NOTURNO
# SG_UF
# TP_CATEGORIA_ADMINISTRATIVA
# TP_DIMENSAO
# TP_GRAU_ACADEMICO
# TP_MODALIDADE_ENSINO
# TP_NIVEL_ACADEMICO
# TP_ORGANIZACAO_ACADEMICA
# TP_REDE
#
# ====================
# COLUNAS 2020
# ====================
# CO_CINE_AREA_DETALHADA
# CO_CINE_AREA_ESPECIFICA
# CO_CINE_AREA_GERAL
# CO_CINE_ROTULO2
# CO_CURSO
# CO_IES
# CO_MUNICIPIO
# CO_REGIAO
# CO_UF
# IN_CAPITAL
# IN_GRATUITO
# NO_CINE_AREA_DETALHADA
# NO_CINE_AREA_ESPECIFICA
# NO_CINE_AREA_GERAL
# NO_CINE_ROTULO
# NO_CURSO
# NO_MUNICIPIO
# NO_REGIAO
# NO_UF
# NU_ANO_CENSO
# QT_ALUNO_DEFICIENTE
# QT_APOIO_SOCIAL
# QT_ATIV_EXTRACURRICULAR
# QT_CONC
# QT_CONC_0_17
# QT_CONC_18_24
# QT_CONC_25_29
# QT_CONC_30_34
# QT_CONC_35_39
# QT_CONC_40_49
# QT_CONC_50_59
# QT_CONC_60_MAIS
# QT_CONC_AMARELA
# QT_CONC_APOIO_SOCIAL
# QT_CONC_ATIV_EXTRACURRICULAR
# QT_CONC_BRANCA
# QT_CONC_CORND
# QT_CONC_DEFICIENTE
# QT_CONC_DIURNO
# QT_CONC_FEM
# QT_CONC_FIES
# QT_CONC_FINANC
# QT_CONC_FINANC_NREEMB
# QT_CONC_FINANC_NREEMB_OUTROS
# QT_CONC_FINANC_REEMB
# QT_CONC_FINANC_REEMB_OUTROS
# QT_CONC_INDIGENA
# QT_CONC_MASC
# QT_CONC_MOB_ACADEMICA
# QT_CONC_NACBRAS
# QT_CONC_NACESTRANG
# QT_CONC_NOTURNO
# QT_CONC_NRPFIES
# QT_CONC_PARDA
# QT_CONC_PARFOR
# QT_CONC_PRETA
# QT_CONC_PROCESCPRIVADA
# QT_CONC_PROCESCPUBLICA
# QT_CONC_PROCNAOINFORMADA
# QT_CONC_PROUNII
# QT_CONC_PROUNIP
# QT_CONC_RESERVA_VAGA
# QT_CONC_RPFIES
# QT_CONC_RVETNICO
# QT_CONC_RVOUTROS
# QT_CONC_RVPDEF
# QT_CONC_RVREDEPUBLICA
# QT_CONC_RVSOCIAL_RF
# QT_CURSO
# QT_ING
# QT_ING_0_17
# QT_ING_18_24
# QT_ING_25_29
# QT_ING_30_34
# QT_ING_35_39
# QT_ING_40_49
# QT_ING_50_59
# QT_ING_60_MAIS
# QT_ING_AMARELA
# QT_ING_APOIO_SOCIAL
# QT_ING_ATIV_EXTRACURRICULAR
# QT_ING_AVALIACAO_SERIADA
# QT_ING_BRANCA
# QT_ING_CORND
# QT_ING_DEFICIENTE
# QT_ING_DIURNO
# QT_ING_EGR
# QT_ING_ENEM
# QT_ING_FEM
# QT_ING_FIES
# QT_ING_FINANC
# QT_ING_FINANC_NREEMB
# QT_ING_FINANC_NREEMB_OUTROS
# QT_ING_FINANC_REEMB
# QT_ING_FINANC_REEMB_OUTROS
# QT_ING_INDIGENA
# QT_ING_MASC
# QT_ING_MOB_ACADEMICA
# QT_ING_NACBRAS
# QT_ING_NACESTRANG
# QT_ING_NOTURNO
# QT_ING_NRPFIES
# QT_ING_OUTRA_FORMA
# QT_ING_OUTRO_TIPO_SELECAO
# QT_ING_PARDA
# QT_ING_PARFOR
# QT_ING_PRETA
# QT_ING_PROCESCPRIVADA
# QT_ING_PROCESCPUBLICA
# QT_ING_PROCNAOINFORMADA
# QT_ING_PROC_SELETIVO
# QT_ING_PROUNII
# QT_ING_PROUNIP
# QT_ING_RESERVA_VAGA
# QT_ING_RPFIES
# QT_ING_RVETNICO
# QT_ING_RVOUTROS
# QT_ING_RVPDEF
# QT_ING_RVREDEPUBLICA
# QT_ING_RVSOCIAL_RF
# QT_ING_SELECAO_SIMPLIFICA
# QT_ING_VESTIBULAR
# QT_ING_VG_NOVA
# QT_ING_VG_PROG_ESPECIAL
# QT_ING_VG_REMANESC
# QT_INSCRITO_TOTAL
# QT_INSCRITO_TOTAL_DIURNO
# QT_INSCRITO_TOTAL_EAD
# QT_INSCRITO_TOTAL_NOTURNO
# QT_INSC_PROC_SELETIVO
# QT_INSC_VG_NOVA
# QT_INSC_VG_PROG_ESPECIAL
# QT_INSC_VG_REMANESC
# QT_MAT
# QT_MAT_0_17
# QT_MAT_18_24
# QT_MAT_25_29
# QT_MAT_30_34
# QT_MAT_35_39
# QT_MAT_40_49
# QT_MAT_50_59
# QT_MAT_60_MAIS
# QT_MAT_AMARELA
# QT_MAT_APOIO_SOCIAL
# QT_MAT_ATIV_EXTRACURRICULAR
# QT_MAT_BRANCA
# QT_MAT_CORND
# QT_MAT_DEFICIENTE
# QT_MAT_DIURNO
# QT_MAT_FEM
# QT_MAT_FIES
# QT_MAT_FINANC
# QT_MAT_FINANC_NREEMB
# QT_MAT_FINANC_NREEMB_OUTROS
# QT_MAT_FINANC_REEMB
# QT_MAT_FINANC_REEMB_OUTROS
# QT_MAT_INDIGENA
# QT_MAT_MASC
# QT_MAT_MOB_ACADEMICA
# QT_MAT_NACBRAS
# QT_MAT_NACESTRANG
# QT_MAT_NOTURNO
# QT_MAT_NRPFIES
# QT_MAT_PARDA
# QT_MAT_PARFOR
# QT_MAT_PRETA
# QT_MAT_PROCESCPRIVADA
# QT_MAT_PROCESCPUBLICA
# QT_MAT_PROCNAOINFORMADA
# QT_MAT_PROUNII
# QT_MAT_PROUNIP
# QT_MAT_RESERVA_VAGA
# QT_MAT_RPFIES
# QT_MAT_RVETNICO
# QT_MAT_RVOUTROS
# QT_MAT_RVPDEF
# QT_MAT_RVREDEPUBLICA
# QT_MAT_RVSOCIAL_RF
# QT_MOB_ACADEMICA
# QT_PARFOR
# QT_SIT_DESVINCULADO
# QT_SIT_FALECIDO
# QT_SIT_TRANCADA
# QT_SIT_TRANSFERIDO
# QT_VG_NOVA
# QT_VG_PROC_SELETIVO
# QT_VG_PROG_ESPECIAL
# QT_VG_REMANESC
# QT_VG_TOTAL
# QT_VG_TOTAL_DIURNO
# QT_VG_TOTAL_EAD
# QT_VG_TOTAL_NOTURNO
# SG_UF
# TP_CATEGORIA_ADMINISTRATIVA
# TP_DIMENSAO
# TP_GRAU_ACADEMICO
# TP_MODALIDADE_ENSINO
# TP_NIVEL_ACADEMICO
# TP_ORGANIZACAO_ACADEMICA
# TP_REDE
#
# ====================
# COLUNAS 2021
# ====================
# CO_CINE_AREA_DETALHADA
# CO_CINE_AREA_ESPECIFICA
# CO_CINE_AREA_GERAL
# CO_CINE_ROTULO
# CO_CURSO
# CO_IES
# CO_MUNICIPIO
# CO_REGIAO
# CO_UF
# IN_CAPITAL
# IN_GRATUITO
# NO_CINE_AREA_DETALHADA
# NO_CINE_AREA_ESPECIFICA
# NO_CINE_AREA_GERAL
# NO_CINE_ROTULO
# NO_CURSO
# NO_MUNICIPIO
# NO_REGIAO
# NO_UF
# NU_ANO_CENSO
# QT_ALUNO_DEFICIENTE
# QT_APOIO_SOCIAL
# QT_ATIV_EXTRACURRICULAR
# QT_CONC
# QT_CONC_0_17
# QT_CONC_18_24
# QT_CONC_25_29
# QT_CONC_30_34
# QT_CONC_35_39
# QT_CONC_40_49
# QT_CONC_50_59
# QT_CONC_60_MAIS
# QT_CONC_AMARELA
# QT_CONC_APOIO_SOCIAL
# QT_CONC_ATIV_EXTRACURRICULAR
# QT_CONC_BRANCA
# QT_CONC_CORND
# QT_CONC_DEFICIENTE
# QT_CONC_DIURNO
# QT_CONC_FEM
# QT_CONC_FIES
# QT_CONC_FINANC
# QT_CONC_FINANC_NREEMB
# QT_CONC_FINANC_NREEMB_OUTROS
# QT_CONC_FINANC_REEMB
# QT_CONC_FINANC_REEMB_OUTROS
# QT_CONC_INDIGENA
# QT_CONC_MASC
# QT_CONC_MOB_ACADEMICA
# QT_CONC_NACBRAS
# QT_CONC_NACESTRANG
# QT_CONC_NOTURNO
# QT_CONC_NRPFIES
# QT_CONC_PARDA
# QT_CONC_PARFOR
# QT_CONC_PRETA
# QT_CONC_PROCESCPRIVADA
# QT_CONC_PROCESCPUBLICA
# QT_CONC_PROCNAOINFORMADA
# QT_CONC_PROUNII
# QT_CONC_PROUNIP
# QT_CONC_RESERVA_VAGA
# QT_CONC_RPFIES
# QT_CONC_RVETNICO
# QT_CONC_RVOUTROS
# QT_CONC_RVPDEF
# QT_CONC_RVREDEPUBLICA
# QT_CONC_RVSOCIAL_RF
# QT_CURSO
# QT_ING
# QT_ING_0_17
# QT_ING_18_24
# QT_ING_25_29
# QT_ING_30_34
# QT_ING_35_39
# QT_ING_40_49
# QT_ING_50_59
# QT_ING_60_MAIS
# QT_ING_AMARELA
# QT_ING_APOIO_SOCIAL
# QT_ING_ATIV_EXTRACURRICULAR
# QT_ING_AVALIACAO_SERIADA
# QT_ING_BRANCA
# QT_ING_CORND
# QT_ING_DEFICIENTE
# QT_ING_DIURNO
# QT_ING_EGR
# QT_ING_ENEM
# QT_ING_FEM
# QT_ING_FIES
# QT_ING_FINANC
# QT_ING_FINANC_NREEMB
# QT_ING_FINANC_NREEMB_OUTROS
# QT_ING_FINANC_REEMB
# QT_ING_FINANC_REEMB_OUTROS
# QT_ING_INDIGENA
# QT_ING_MASC
# QT_ING_MOB_ACADEMICA
# QT_ING_NACBRAS
# QT_ING_NACESTRANG
# QT_ING_NOTURNO
# QT_ING_NRPFIES
# QT_ING_OUTRA_FORMA
# QT_ING_OUTRO_TIPO_SELECAO
# QT_ING_PARDA
# QT_ING_PARFOR
# QT_ING_PRETA
# QT_ING_PROCESCPRIVADA
# QT_ING_PROCESCPUBLICA
# QT_ING_PROCNAOINFORMADA
# QT_ING_PROC_SELETIVO
# QT_ING_PROUNII
# QT_ING_PROUNIP
# QT_ING_RESERVA_VAGA
# QT_ING_RPFIES
# QT_ING_RVETNICO
# QT_ING_RVOUTROS
# QT_ING_RVPDEF
# QT_ING_RVREDEPUBLICA
# QT_ING_RVSOCIAL_RF
# QT_ING_SELECAO_SIMPLIFICA
# QT_ING_VESTIBULAR
# QT_ING_VG_NOVA
# QT_ING_VG_PROG_ESPECIAL
# QT_ING_VG_REMANESC
# QT_INSCRITO_TOTAL
# QT_INSCRITO_TOTAL_DIURNO
# QT_INSCRITO_TOTAL_EAD
# QT_INSCRITO_TOTAL_NOTURNO
# QT_INSC_PROC_SELETIVO
# QT_INSC_VG_NOVA
# QT_INSC_VG_PROG_ESPECIAL
# QT_INSC_VG_REMANESC
# QT_MAT
# QT_MAT_0_17
# QT_MAT_18_24
# QT_MAT_25_29
# QT_MAT_30_34
# QT_MAT_35_39
# QT_MAT_40_49
# QT_MAT_50_59
# QT_MAT_60_MAIS
# QT_MAT_AMARELA
# QT_MAT_APOIO_SOCIAL
# QT_MAT_ATIV_EXTRACURRICULAR
# QT_MAT_BRANCA
# QT_MAT_CORND
# QT_MAT_DEFICIENTE
# QT_MAT_DIURNO
# QT_MAT_FEM
# QT_MAT_FIES
# QT_MAT_FINANC
# QT_MAT_FINANC_NREEMB
# QT_MAT_FINANC_NREEMB_OUTROS
# QT_MAT_FINANC_REEMB
# QT_MAT_FINANC_REEMB_OUTROS
# QT_MAT_INDIGENA
# QT_MAT_MASC
# QT_MAT_MOB_ACADEMICA
# QT_MAT_NACBRAS
# QT_MAT_NACESTRANG
# QT_MAT_NOTURNO
# QT_MAT_NRPFIES
# QT_MAT_PARDA
# QT_MAT_PARFOR
# QT_MAT_PRETA
# QT_MAT_PROCESCPRIVADA
# QT_MAT_PROCESCPUBLICA
# QT_MAT_PROCNAOINFORMADA
# QT_MAT_PROUNII
# QT_MAT_PROUNIP
# QT_MAT_RESERVA_VAGA
# QT_MAT_RPFIES
# QT_MAT_RVETNICO
# QT_MAT_RVOUTROS
# QT_MAT_RVPDEF
# QT_MAT_RVREDEPUBLICA
# QT_MAT_RVSOCIAL_RF
# QT_MOB_ACADEMICA
# QT_PARFOR
# QT_SIT_DESVINCULADO
# QT_SIT_FALECIDO
# QT_SIT_TRANCADA
# QT_SIT_TRANSFERIDO
# QT_VG_NOVA
# QT_VG_PROC_SELETIVO
# QT_VG_PROG_ESPECIAL
# QT_VG_REMANESC
# QT_VG_TOTAL
# QT_VG_TOTAL_DIURNO
# QT_VG_TOTAL_EAD
# QT_VG_TOTAL_NOTURNO
# SG_UF
# TP_CATEGORIA_ADMINISTRATIVA
# TP_DIMENSAO
# TP_GRAU_ACADEMICO
# TP_MODALIDADE_ENSINO
# TP_NIVEL_ACADEMICO
# TP_ORGANIZACAO_ACADEMICA
# TP_REDE
#
# ====================
# COLUNAS 2022
# ====================
# CO_CINE_AREA_DETALHADA
# CO_CINE_AREA_ESPECIFICA
# CO_CINE_AREA_GERAL
# CO_CINE_ROTULO
# CO_CURSO
# CO_IES
# CO_MUNICIPIO
# CO_REGIAO
# CO_UF
# IN_CAPITAL
# IN_GRATUITO
# NO_CINE_AREA_DETALHADA
# NO_CINE_AREA_ESPECIFICA
# NO_CINE_AREA_GERAL
# NO_CINE_ROTULO
# NO_CURSO
# NO_MUNICIPIO
# NO_REGIAO
# NO_UF
# NU_ANO_CENSO
# QT_ALUNO_DEFICIENTE
# QT_APOIO_SOCIAL
# QT_ATIV_EXTRACURRICULAR
# QT_CONC
# QT_CONC_0_17
# QT_CONC_18_24
# QT_CONC_25_29
# QT_CONC_30_34
# QT_CONC_35_39
# QT_CONC_40_49
# QT_CONC_50_59
# QT_CONC_60_MAIS
# QT_CONC_AMARELA
# QT_CONC_APOIO_SOCIAL
# QT_CONC_ATIV_EXTRACURRICULAR
# QT_CONC_BRANCA
# QT_CONC_CORND
# QT_CONC_DEFICIENTE
# QT_CONC_DIURNO
# QT_CONC_FEM
# QT_CONC_FIES
# QT_CONC_FINANC
# QT_CONC_FINANC_NREEMB
# QT_CONC_FINANC_NREEMB_OUTROS
# QT_CONC_FINANC_REEMB
# QT_CONC_FINANC_REEMB_OUTROS
# QT_CONC_INDIGENA
# QT_CONC_MASC
# QT_CONC_MOB_ACADEMICA
# QT_CONC_NACBRAS
# QT_CONC_NACESTRANG
# QT_CONC_NOTURNO
# QT_CONC_NRPFIES
# QT_CONC_PARDA
# QT_CONC_PARFOR
# QT_CONC_PRETA
# QT_CONC_PROCESCPRIVADA
# QT_CONC_PROCESCPUBLICA
# QT_CONC_PROCNAOINFORMADA
# QT_CONC_PROUNII
# QT_CONC_PROUNIP
# QT_CONC_RESERVA_VAGA
# QT_CONC_RPFIES
# QT_CONC_RVETNICO
# QT_CONC_RVOUTROS
# QT_CONC_RVPDEF
# QT_CONC_RVREDEPUBLICA
# QT_CONC_RVSOCIAL_RF
# QT_CURSO
# QT_ING
# QT_ING_0_17
# QT_ING_18_24
# QT_ING_25_29
# QT_ING_30_34
# QT_ING_35_39
# QT_ING_40_49
# QT_ING_50_59
# QT_ING_60_MAIS
# QT_ING_AMARELA
# QT_ING_APOIO_SOCIAL
# QT_ING_ATIV_EXTRACURRICULAR
# QT_ING_AVALIACAO_SERIADA
# QT_ING_BRANCA
# QT_ING_CORND
# QT_ING_DEFICIENTE
# QT_ING_DIURNO
# QT_ING_EGR
# QT_ING_ENEM
# QT_ING_FEM
# QT_ING_FIES
# QT_ING_FINANC
# QT_ING_FINANC_NREEMB
# QT_ING_FINANC_NREEMB_OUTROS
# QT_ING_FINANC_REEMB
# QT_ING_FINANC_REEMB_OUTROS
# QT_ING_INDIGENA
# QT_ING_MASC
# QT_ING_MOB_ACADEMICA
# QT_ING_NACBRAS
# QT_ING_NACESTRANG
# QT_ING_NOTURNO
# QT_ING_NRPFIES
# QT_ING_OUTRA_FORMA
# QT_ING_OUTRO_TIPO_SELECAO
# QT_ING_PARDA
# QT_ING_PARFOR
# QT_ING_PRETA
# QT_ING_PROCESCPRIVADA
# QT_ING_PROCESCPUBLICA
# QT_ING_PROCNAOINFORMADA
# QT_ING_PROC_SELETIVO
# QT_ING_PROUNII
# QT_ING_PROUNIP
# QT_ING_RESERVA_VAGA
# QT_ING_RPFIES
# QT_ING_RVETNICO
# QT_ING_RVOUTROS
# QT_ING_RVPDEF
# QT_ING_RVREDEPUBLICA
# QT_ING_RVSOCIAL_RF
# QT_ING_SELECAO_SIMPLIFICA
# QT_ING_VESTIBULAR
# QT_ING_VG_NOVA
# QT_ING_VG_PROG_ESPECIAL
# QT_ING_VG_REMANESC
# QT_INSCRITO_TOTAL
# QT_INSCRITO_TOTAL_DIURNO
# QT_INSCRITO_TOTAL_EAD
# QT_INSCRITO_TOTAL_NOTURNO
# QT_INSC_PROC_SELETIVO
# QT_INSC_VG_NOVA
# QT_INSC_VG_PROG_ESPECIAL
# QT_INSC_VG_REMANESC
# QT_MAT
# QT_MAT_0_17
# QT_MAT_18_24
# QT_MAT_25_29
# QT_MAT_30_34
# QT_MAT_35_39
# QT_MAT_40_49
# QT_MAT_50_59
# QT_MAT_60_MAIS
# QT_MAT_AMARELA
# QT_MAT_APOIO_SOCIAL
# QT_MAT_ATIV_EXTRACURRICULAR
# QT_MAT_BRANCA
# QT_MAT_CORND
# QT_MAT_DEFICIENTE
# QT_MAT_DIURNO
# QT_MAT_FEM
# QT_MAT_FIES
# QT_MAT_FINANC
# QT_MAT_FINANC_NREEMB
# QT_MAT_FINANC_NREEMB_OUTROS
# QT_MAT_FINANC_REEMB
# QT_MAT_FINANC_REEMB_OUTROS
# QT_MAT_INDIGENA
# QT_MAT_MASC
# QT_MAT_MOB_ACADEMICA
# QT_MAT_NACBRAS
# QT_MAT_NACESTRANG
# QT_MAT_NOTURNO
# QT_MAT_NRPFIES
# QT_MAT_PARDA
# QT_MAT_PARFOR
# QT_MAT_PRETA
# QT_MAT_PROCESCPRIVADA
# QT_MAT_PROCESCPUBLICA
# QT_MAT_PROCNAOINFORMADA
# QT_MAT_PROUNII
# QT_MAT_PROUNIP
# QT_MAT_RESERVA_VAGA
# QT_MAT_RPFIES
# QT_MAT_RVETNICO
# QT_MAT_RVOUTROS
# QT_MAT_RVPDEF
# QT_MAT_RVREDEPUBLICA
# QT_MAT_RVSOCIAL_RF
# QT_MOB_ACADEMICA
# QT_PARFOR
# QT_SIT_DESVINCULADO
# QT_SIT_FALECIDO
# QT_SIT_TRANCADA
# QT_SIT_TRANSFERIDO
# QT_VG_NOVA
# QT_VG_PROC_SELETIVO
# QT_VG_PROG_ESPECIAL
# QT_VG_REMANESC
# QT_VG_TOTAL
# QT_VG_TOTAL_DIURNO
# QT_VG_TOTAL_EAD
# QT_VG_TOTAL_NOTURNO
# SG_UF
# TP_CATEGORIA_ADMINISTRATIVA
# TP_DIMENSAO
# TP_GRAU_ACADEMICO
# TP_MODALIDADE_ENSINO
# TP_NIVEL_ACADEMICO
# TP_ORGANIZACAO_ACADEMICA
# TP_REDE
#
# ====================
# COLUNAS 2023
# ====================
# CO_CINE_AREA_DETALHADA
# CO_CINE_AREA_ESPECIFICA
# CO_CINE_AREA_GERAL
# CO_CINE_ROTULO
# CO_CURSO
# CO_IES
# CO_MUNICIPIO
# CO_REGIAO
# CO_UF
# IN_CAPITAL
# IN_COMUNITARIA
# IN_CONFESSIONAL
# IN_GRATUITO
# NO_CINE_AREA_DETALHADA
# NO_CINE_AREA_ESPECIFICA
# NO_CINE_AREA_GERAL
# NO_CINE_ROTULO
# NO_CURSO
# NO_MUNICIPIO
# NO_REGIAO
# NO_UF
# NU_ANO_CENSO
# QT_ALUNO_DEFICIENTE
# QT_APOIO_SOCIAL
# QT_ATIV_EXTRACURRICULAR
# QT_CONC
# QT_CONC_0_17
# QT_CONC_18_24
# QT_CONC_25_29
# QT_CONC_30_34
# QT_CONC_35_39
# QT_CONC_40_49
# QT_CONC_50_59
# QT_CONC_60_MAIS
# QT_CONC_AMARELA
# QT_CONC_APOIO_SOCIAL
# QT_CONC_ATIV_EXTRACURRICULAR
# QT_CONC_BRANCA
# QT_CONC_CORND
# QT_CONC_DEFICIENTE
# QT_CONC_DIURNO
# QT_CONC_FEM
# QT_CONC_FIES
# QT_CONC_FINANC
# QT_CONC_FINANC_NREEMB
# QT_CONC_FINANC_NREEMB_OUTROS
# QT_CONC_FINANC_REEMB
# QT_CONC_FINANC_REEMB_OUTROS
# QT_CONC_INDIGENA
# QT_CONC_MASC
# QT_CONC_MOB_ACADEMICA
# QT_CONC_NACBRAS
# QT_CONC_NACESTRANG
# QT_CONC_NOTURNO
# QT_CONC_NRPFIES
# QT_CONC_PARDA
# QT_CONC_PARFOR
# QT_CONC_PRETA
# QT_CONC_PROCESCPRIVADA
# QT_CONC_PROCESCPUBLICA
# QT_CONC_PROCNAOINFORMADA
# QT_CONC_PROUNII
# QT_CONC_PROUNIP
# QT_CONC_RESERVA_VAGA
# QT_CONC_RPFIES
# QT_CONC_RVETNICO
# QT_CONC_RVOUTROS
# QT_CONC_RVPDEF
# QT_CONC_RVREDEPUBLICA
# QT_CONC_RVSOCIAL_RF
# QT_CURSO
# QT_ING
# QT_ING_0_17
# QT_ING_18_24
# QT_ING_25_29
# QT_ING_30_34
# QT_ING_35_39
# QT_ING_40_49
# QT_ING_50_59
# QT_ING_60_MAIS
# QT_ING_AMARELA
# QT_ING_APOIO_SOCIAL
# QT_ING_ATIV_EXTRACURRICULAR
# QT_ING_AVALIACAO_SERIADA
# QT_ING_BRANCA
# QT_ING_CORND
# QT_ING_DEFICIENTE
# QT_ING_DIURNO
# QT_ING_EGR
# QT_ING_ENEM
# QT_ING_FEM
# QT_ING_FIES
# QT_ING_FINANC
# QT_ING_FINANC_NREEMB
# QT_ING_FINANC_NREEMB_OUTROS
# QT_ING_FINANC_REEMB
# QT_ING_FINANC_REEMB_OUTROS
# QT_ING_INDIGENA
# QT_ING_MASC
# QT_ING_MOB_ACADEMICA
# QT_ING_NACBRAS
# QT_ING_NACESTRANG
# QT_ING_NOTURNO
# QT_ING_NRPFIES
# QT_ING_OUTRA_FORMA
# QT_ING_OUTRO_TIPO_SELECAO
# QT_ING_PARDA
# QT_ING_PARFOR
# QT_ING_PRETA
# QT_ING_PROCESCPRIVADA
# QT_ING_PROCESCPUBLICA
# QT_ING_PROCNAOINFORMADA
# QT_ING_PROC_SELETIVO
# QT_ING_PROUNII
# QT_ING_PROUNIP
# QT_ING_RESERVA_VAGA
# QT_ING_RPFIES
# QT_ING_RVETNICO
# QT_ING_RVOUTROS
# QT_ING_RVPDEF
# QT_ING_RVREDEPUBLICA
# QT_ING_RVSOCIAL_RF
# QT_ING_SELECAO_SIMPLIFICA
# QT_ING_VESTIBULAR
# QT_ING_VG_NOVA
# QT_ING_VG_PROG_ESPECIAL
# QT_ING_VG_REMANESC
# QT_INSCRITO_TOTAL
# QT_INSCRITO_TOTAL_DIURNO
# QT_INSCRITO_TOTAL_EAD
# QT_INSCRITO_TOTAL_NOTURNO
# QT_INSC_PROC_SELETIVO
# QT_INSC_VG_NOVA
# QT_INSC_VG_PROG_ESPECIAL
# QT_INSC_VG_REMANESC
# QT_MAT
# QT_MAT_0_17
# QT_MAT_18_24
# QT_MAT_25_29
# QT_MAT_30_34
# QT_MAT_35_39
# QT_MAT_40_49
# QT_MAT_50_59
# QT_MAT_60_MAIS
# QT_MAT_AMARELA
# QT_MAT_APOIO_SOCIAL
# QT_MAT_ATIV_EXTRACURRICULAR
# QT_MAT_BRANCA
# QT_MAT_CORND
# QT_MAT_DEFICIENTE
# QT_MAT_DIURNO
# QT_MAT_FEM
# QT_MAT_FIES
# QT_MAT_FINANC
# QT_MAT_FINANC_NREEMB
# QT_MAT_FINANC_NREEMB_OUTROS
# QT_MAT_FINANC_REEMB
# QT_MAT_FINANC_REEMB_OUTROS
# QT_MAT_INDIGENA
# QT_MAT_MASC
# QT_MAT_MOB_ACADEMICA
# QT_MAT_NACBRAS
# QT_MAT_NACESTRANG
# QT_MAT_NOTURNO
# QT_MAT_NRPFIES
# QT_MAT_PARDA
# QT_MAT_PARFOR
# QT_MAT_PRETA
# QT_MAT_PROCESCPRIVADA
# QT_MAT_PROCESCPUBLICA
# QT_MAT_PROCNAOINFORMADA
# QT_MAT_PROUNII
# QT_MAT_PROUNIP
# QT_MAT_RESERVA_VAGA
# QT_MAT_RPFIES
# QT_MAT_RVETNICO
# QT_MAT_RVOUTROS
# QT_MAT_RVPDEF
# QT_MAT_RVREDEPUBLICA
# QT_MAT_RVSOCIAL_RF
# QT_MOB_ACADEMICA
# QT_PARFOR
# QT_SIT_DESVINCULADO
# QT_SIT_FALECIDO
# QT_SIT_TRANCADA
# QT_SIT_TRANSFERIDO
# QT_VG_NOVA
# QT_VG_PROC_SELETIVO
# QT_VG_PROG_ESPECIAL
# QT_VG_REMANESC
# QT_VG_TOTAL
# QT_VG_TOTAL_DIURNO
# QT_VG_TOTAL_EAD
# QT_VG_TOTAL_NOTURNO
# SG_UF
# TP_CATEGORIA_ADMINISTRATIVA
# TP_DIMENSAO
# TP_GRAU_ACADEMICO
# TP_MODALIDADE_ENSINO
# TP_NIVEL_ACADEMICO
# TP_ORGANIZACAO_ACADEMICA
# TP_REDE
#
# ====================
# COLUNAS 2024
# ====================
# CO_CINE_AREA_DETALHADA
# CO_CINE_AREA_ESPECIFICA
# CO_CINE_AREA_GERAL
# CO_CINE_ROTULO
# CO_CURSO
# CO_IES
# CO_MUNICIPIO
# CO_REGIAO
# CO_UF
# IN_CAPITAL
# IN_COMUNITARIA
# IN_CONFESSIONAL
# IN_GRATUITO
# NO_CINE_AREA_DETALHADA
# NO_CINE_AREA_ESPECIFICA
# NO_CINE_AREA_GERAL
# NO_CINE_ROTULO
# NO_CURSO
# NO_MUNICIPIO
# NO_REGIAO
# NO_UF
# NU_ANO_CENSO
# QT_ALUNO_DEFICIENTE
# QT_APOIO_SOCIAL
# QT_ATIV_EXTRACURRICULAR
# QT_CONC
# QT_CONC_0_17
# QT_CONC_18_24
# QT_CONC_25_29
# QT_CONC_30_34
# QT_CONC_35_39
# QT_CONC_40_49
# QT_CONC_50_59
# QT_CONC_60_MAIS
# QT_CONC_AMARELA
# QT_CONC_APOIO_SOCIAL
# QT_CONC_ATIV_EXTRACURRICULAR
# QT_CONC_BRANCA
# QT_CONC_CORND
# QT_CONC_DEFICIENTE
# QT_CONC_DIURNO
# QT_CONC_FEM
# QT_CONC_FIES
# QT_CONC_FINANC
# QT_CONC_FINANC_NREEMB
# QT_CONC_FINANC_NREEMB_OUTROS
# QT_CONC_FINANC_REEMB
# QT_CONC_FINANC_REEMB_OUTROS
# QT_CONC_INDIGENA
# QT_CONC_MASC
# QT_CONC_MOB_ACADEMICA
# QT_CONC_NACBRAS
# QT_CONC_NACESTRANG
# QT_CONC_NOTURNO
# QT_CONC_NRPFIES
# QT_CONC_PARDA
# QT_CONC_PARFOR
# QT_CONC_PRETA
# QT_CONC_PROCESCPRIVADA
# QT_CONC_PROCESCPUBLICA
# QT_CONC_PROCNAOINFORMADA
# QT_CONC_PROUNII
# QT_CONC_PROUNIP
# QT_CONC_RESERVA_VAGA
# QT_CONC_RPFIES
# QT_CONC_RVIDOSO
# QT_CONC_RVINTERN
# QT_CONC_RVMEDAL
# QT_CONC_RVOUTROS
# QT_CONC_RVPDEF
# QT_CONC_RVPOVT
# QT_CONC_RVPPI
# QT_CONC_RVQUILO
# QT_CONC_RVREDEPUBLICA
# QT_CONC_RVREFU
# QT_CONC_RVSOCIAL_RF
# QT_CONC_RVTRANS
# QT_CURSO
# QT_ING
# QT_ING_0_17
# QT_ING_18_24
# QT_ING_25_29
# QT_ING_30_34
# QT_ING_35_39
# QT_ING_40_49
# QT_ING_50_59
# QT_ING_60_MAIS
# QT_ING_AMARELA
# QT_ING_APOIO_SOCIAL
# QT_ING_ATIV_EXTRACURRICULAR
# QT_ING_AVALIACAO_SERIADA
# QT_ING_BRANCA
# QT_ING_CORND
# QT_ING_DEFICIENTE
# QT_ING_DIURNO
# QT_ING_EGR
# QT_ING_ENEM
# QT_ING_FEM
# QT_ING_FIES
# QT_ING_FINANC
# QT_ING_FINANC_NREEMB
# QT_ING_FINANC_NREEMB_OUTROS
# QT_ING_FINANC_REEMB
# QT_ING_FINANC_REEMB_OUTROS
# QT_ING_INDIGENA
# QT_ING_MASC
# QT_ING_MOB_ACADEMICA
# QT_ING_NACBRAS
# QT_ING_NACESTRANG
# QT_ING_NOTURNO
# QT_ING_NRPFIES
# QT_ING_OUTRA_FORMA
# QT_ING_OUTRO_TIPO_SELECAO
# QT_ING_PARDA
# QT_ING_PARFOR
# QT_ING_PRETA
# QT_ING_PROCESCPRIVADA
# QT_ING_PROCESCPUBLICA
# QT_ING_PROCNAOINFORMADA
# QT_ING_PROC_SELETIVO
# QT_ING_PROUNII
# QT_ING_PROUNIP
# QT_ING_RESERVA_VAGA
# QT_ING_RPFIES
# QT_ING_RVIDOSO
# QT_ING_RVINTERN
# QT_ING_RVMEDAL
# QT_ING_RVOUTROS
# QT_ING_RVPDEF
# QT_ING_RVPOVT
# QT_ING_RVPPI
# QT_ING_RVQUILO
# QT_ING_RVREDEPUBLICA
# QT_ING_RVREFU
# QT_ING_RVSOCIAL_RF
# QT_ING_RVTRANS
# QT_ING_SELECAO_SIMPLIFICA
# QT_ING_VESTIBULAR
# QT_ING_VG_NOVA
# QT_ING_VG_PROG_ESPECIAL
# QT_ING_VG_REMANESC
# QT_INSCRITO_TOTAL
# QT_INSCRITO_TOTAL_DIURNO
# QT_INSCRITO_TOTAL_EAD
# QT_INSCRITO_TOTAL_NOTURNO
# QT_INSC_PROC_SELETIVO
# QT_INSC_VG_NOVA
# QT_INSC_VG_PROG_ESPECIAL
# QT_INSC_VG_REMANESC
# QT_MAT
# QT_MAT_0_17
# QT_MAT_18_24
# QT_MAT_25_29
# QT_MAT_30_34
# QT_MAT_35_39
# QT_MAT_40_49
# QT_MAT_50_59
# QT_MAT_60_MAIS
# QT_MAT_AMARELA
# QT_MAT_APOIO_SOCIAL
# QT_MAT_ATIV_EXTRACURRICULAR
# QT_MAT_BRANCA
# QT_MAT_CORND
# QT_MAT_DEFICIENTE
# QT_MAT_DIURNO
# QT_MAT_FEM
# QT_MAT_FIES
# QT_MAT_FINANC
# QT_MAT_FINANC_NREEMB
# QT_MAT_FINANC_NREEMB_OUTROS
# QT_MAT_FINANC_REEMB
# QT_MAT_FINANC_REEMB_OUTROS
# QT_MAT_INDIGENA
# QT_MAT_MASC
# QT_MAT_MOB_ACADEMICA
# QT_MAT_NACBRAS
# QT_MAT_NACESTRANG
# QT_MAT_NOTURNO
# QT_MAT_NRPFIES
# QT_MAT_PARDA
# QT_MAT_PARFOR
# QT_MAT_PRETA
# QT_MAT_PROCESCPRIVADA
# QT_MAT_PROCESCPUBLICA
# QT_MAT_PROCNAOINFORMADA
# QT_MAT_PROUNII
# QT_MAT_PROUNIP
# QT_MAT_RESERVA_VAGA
# QT_MAT_RPFIES
# QT_MAT_RVIDOSO
# QT_MAT_RVINTERN
# QT_MAT_RVMEDAL
# QT_MAT_RVOUTROS
# QT_MAT_RVPDEF
# QT_MAT_RVPOVT
# QT_MAT_RVPPI
# QT_MAT_RVQUILO
# QT_MAT_RVREDEPUBLICA
# QT_MAT_RVREFU
# QT_MAT_RVSOCIAL_RF
# QT_MAT_RVTRANS
# QT_MOB_ACADEMICA
# QT_PARFOR
# QT_SIT_DESVINCULADO
# QT_SIT_FALECIDO
# QT_SIT_TRANCADA
# QT_SIT_TRANSFERIDO
# QT_VG_NOVA
# QT_VG_PROC_SELETIVO
# QT_VG_PROG_ESPECIAL
# QT_VG_REMANESC
# QT_VG_TOTAL
# QT_VG_TOTAL_DIURNO
# QT_VG_TOTAL_EAD
# QT_VG_TOTAL_NOTURNO
# SG_UF
# TP_CATEGORIA_ADMINISTRATIVA
# TP_DIMENSAO
# TP_GRAU_ACADEMICO
# TP_MODALIDADE_ENSINO
# TP_NIVEL_ACADEMICO
# TP_ORGANIZACAO_ACADEMICA
# TP_REDE
